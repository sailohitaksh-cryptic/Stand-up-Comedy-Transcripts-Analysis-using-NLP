# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      ladies and gentlemen please welcome the stage ...          Ali Wong
# anthony  thank you thank you thank you san francisco th...  Anthony Jeselnik
# bill     all right thank you thank you very much thank ...         Bill Burr
# dave     this dave tells dirty jokes for living that st...    Dave Chappelle
# gabriel  can you please state your name martin moreno b...  Gabriel Iglesias
# hasan    what davis what home had bring back here netfl...      Hasan Minhaj
# jim      ladies and gentlemen please welcome the stage ...     Jim Jefferies
# joe      ladies and gentlemen welcome joe rogan what th...         Joe Rogan
# john     armed with boyish charm and sharp wit the form...      John Mulaney
# kevin    streaming netflix from november what was looki...        Kevin Hart
# louis    intro fade the music out let roll hold there l...        Louis C.K.
# mike     wow hey thank you thanks thank you guys hey se...    Mike Birbiglia
# ricky    hello hello how you doing great thank you wow ...     Ricky Gervais

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'ladies and gentlemen please welcome the stage ali wong hello welcome thank you thank you for coming hello hello are gonna have get this shit over with cause have pee like ten minutes but thank you eve'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'ladies': ['and', 'home', 'who', 'they', 'and', 'who'],
#  'and': ['gentlemen',
#   'foremost',
#   'then',
#   'have',
#   'there',
#   'then',
#   'resentment',
#   'get',
#   'get',
#   'says',
#   'optimum',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'all',
#   'everybody',
#   'mom',
#   'she',
#   'was',
#   'not',
#   'much',
#   'saw',
#   'was',
#   'the',
#   'was',
#   'trapped',
#   'has',
#   'saw',
#   'had',
#   'the',
#   'then',
#   'dropped',
#   'watched',
#   'was',
#   'have',
#   'that',
#   'you',
#   'recycling',
#   'disturbing',
#   'very',
#   'all',
#   'just',
#   'then',
#   'racist',
#   'half',
#   'spend',
#   'his',
#   'was',
#   'slide',
#   'your',
#   'inflamed',
#   'you',
#   'then',
#   'have',
#   'half',
#   'half',
#   'half',
#   'half',
#   'playing',
#   'rugby',
#   'one',
#   'foremost',
#   'grandma',
#   'the',
#   'emotionally',
#   'are',
#   'percent',
#   'funny',
#   'neither',
#   'had',
#   'just',
#   'then',
#   'too',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'like',
#   'then',
#   'look',
#   'like',
#   'very',
#   'for',
#   'don',
#   'she',
#   'rise',
#   'her',
#   'like',
#   'eat',
#   'watch',
#   'then',
#   'like',
#   'now',
#   'they',
#   'most',
#   'they',
#   'terms',
#   'then',
#   'digitally',
#   'then',
#   'you',
#   'you',
#   'then',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say',
#   'husband',
#   'was',
#   'when',
#   'not',
#   'just',
#   'think',
#   'what',
#   'sicker',
#   'sicker',
#   'sicker',
#   'sicker',
#   'posted',
#   'all',
#   'they',
#   'that',
#   'lies',
#   'result',
#   'treat',
#   'you',
#   'succeed',
#   'they',
#   'like',
#   'you',
#   'like',
#   'then',
#   'that',
#   'out',
#   'tired',
#   'told',
#   'just',
#   'sisters',
#   'half',
#   'unusual',
#   'they',
#   'boring',
#   'all',
#   'their',
#   'wearing',
#   'famous',
#   'they',
#   'you',
#   'just',
#   'therefore',
#   'you',
#   'ignore',
#   'then',
#   'she',
#   'when',
#   'the',
#   'biggie',
#   'and',
#   'scared',
#   'pussy',
#   'your',
#   'there',
#   'did',
#   'lot',
#   'found',
#   'push',
#   'then',
#   'then',
#   'melt',
#   'had',
#   'then',
#   'then',
#   'sniff',
#   'were',
#   'you',
#   'would',
#   'outside',
#   'angry',
#   'rapey',
#   'they',
#   'yeah',
#   'most',
#   'see',
#   'like',
#   'would',
#   'would',
#   'instead',
#   'then',
#   'then',
#   'remember',
#   'then',
#   'hold',
#   'would',
#   'some',
#   'then',
#   'this',
#   'half',
#   'lot',
#   'terrible',
#   'wish',
#   'when',
#   'everything',
#   'the',
#   'was',
#   'then',
#   'was',
#   'most',
#   'was',
#   'felt',
#   'used',
#   'held',
#   'got',
#   'love',
#   'your',
#   'just',
#   'gotta',
#   'already',
#   'also',
#   'leaves',
#   'dark',
#   'then',
#   'naked',
#   'half',
#   'was',
#   'looked',
#   'pussy',
#   'then',
#   'then',
#   'recently',
#   'two',
#   'with',
#   'now',
#   'half',
#   'donald',
#   'why',
#   'where'],
#  'gentlemen': ['please'],
#  'please': ['welcome', 'really', 'hurry', 'look'],
#  'welcome': ['the', 'thank'],
#  'the': ['stage',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'life',
#   'center',
#   'hoarding',
#   'hpv',
#   'country',
#   'third',
#   'communists',
#   'last',
#   'worst',
#   'manual',
#   'calculator',
#   'future',
#   'tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside',
#   'inside',
#   'first',
#   'time',
#   'fifth',
#   'next',
#   'back',
#   'park',
#   'middle',
#   'money',
#   'colonizer',
#   'advantage',
#   'time',
#   'sexiest',
#   'sexiest',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference',
#   'fancy',
#   'chinese',
#   'japanese',
#   'east',
#   'west',
#   'name',
#   'bathroom',
#   'bathroom',
#   'corner',
#   'wait',
#   'wall',
#   'fuck',
#   'house',
#   'idea',
#   'man',
#   'message',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'facebook',
#   'table',
#   'top',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret',
#   'phrase',
#   'street',
#   'boat',
#   'best',
#   'desert',
#   'stall',
#   'end',
#   'day',
#   'goonies',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'images',
#   'internet',
#   'back',
#   'internet',
#   'jewish',
#   'universe',
#   'pain',
#   'pain',
#   'pain',
#   'dick',
#   'butt',
#   'tush',
#   'man',
#   'look',
#   'man',
#   'first',
#   'woman',
#   'lord',
#   'rim',
#   'most',
#   'most',
#   'woman',
#   'time',
#   'boss',
#   'boss',
#   'time',
#   'bedroom',
#   'boss',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby',
#   'dream',
#   'point',
#   'ultimate',
#   'world',
#   'rest',
#   'galapagos',
#   'phrase',
#   'women',
#   'side',
#   'hood',
#   'movie',
#   'park',
#   'sun',
#   'sun',
#   'tupac',
#   'time',
#   'time',
#   'peace',
#   'boat',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood',
#   'eggs',
#   'month',
#   'kraken',
#   'time',
#   'smiley',
#   'ovulation',
#   'time',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'lord',
#   'size',
#   'twins',
#   'toilet',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house',
#   'dishes',
#   'plants',
#   'channel',
#   'star',
#   'show',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same',
#   'escrow',
#   'one',
#   'epicenter',
#   'midterm',
#   'hilarious',
#   'record',
#   'highest',
#   'loft'],
#  'stage': ['ali', 'with', 'week', 'scraps'],
#  'ali': ['wong', 'you', 'have', 'why', 'did', 'wong'],
#  'wong': ['hello', 'have'],
#  'hello': ['welcome', 'hello', 'are'],
#  'thank': ['you', 'you', 'you', 'you', 'you'],
#  'you': ['thank',
#   'for',
#   'everybody',
#   'five',
#   'fuck',
#   'don',
#   'but',
#   'cause',
#   'don',
#   'and',
#   'and',
#   'don',
#   'fucking',
#   'lot',
#   'the',
#   'can',
#   'never',
#   'better',
#   'busy',
#   'under',
#   'never',
#   'might',
#   'die',
#   'wanna',
#   'wanna',
#   'gotta',
#   'homeless',
#   'hipster',
#   'drop',
#   'know',
#   'any',
#   'know',
#   'feel',
#   'feel',
#   'with',
#   'know',
#   'feel',
#   'wes',
#   'know',
#   'about',
#   'cool',
#   'know',
#   'know',
#   'right',
#   'know',
#   'get',
#   'get',
#   'like',
#   'don',
#   'know',
#   'guys',
#   'know',
#   'mess',
#   'like',
#   'guys',
#   'know',
#   'can',
#   'can',
#   'eat',
#   'queef',
#   'know',
#   'gotta',
#   'know',
#   'too',
#   'like',
#   'marry',
#   'something',
#   'like',
#   'would',
#   'don',
#   'know',
#   'know',
#   'have',
#   'could',
#   'about',
#   'can',
#   'always',
#   'paranoid',
#   'like',
#   'hurry',
#   'never',
#   'dare',
#   'know',
#   'deep',
#   'know',
#   'need',
#   'need',
#   'don',
#   'not',
#   'guys',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'tell',
#   'son',
#   'start',
#   'get',
#   'crave',
#   'broke',
#   'idiot',
#   'realize',
#   'know',
#   'ain',
#   'not',
#   'really',
#   'scared',
#   'now',
#   'you',
#   'married',
#   'gonna',
#   'have',
#   'gotta',
#   'gotta',
#   'don',
#   'gotta',
#   'put',
#   'feel',
#   'fucking',
#   'know',
#   'haven',
#   'only',
#   'know',
#   'get',
#   'get',
#   'stick',
#   'know',
#   'just',
#   'the',
#   'the',
#   'know',
#   'are',
#   'all',
#   'know',
#   'right',
#   'respect',
#   'need',
#   'know',
#   'know',
#   'what',
#   'the',
#   'motherfucker',
#   'bossy',
#   'supposed',
#   'have',
#   'little',
#   'know',
#   'know',
#   'made',
#   'eating',
#   'know',
#   'guys',
#   'there',
#   'know',
#   'gonna',
#   'just',
#   'gonna',
#   'gonna',
#   'know',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'could',
#   'slime',
#   'ghostbusters',
#   'scratch',
#   'can',
#   'urgently',
#   'cause',
#   'gotta',
#   'need',
#   'guys',
#   'your',
#   'your',
#   'been',
#   'pee',
#   'when',
#   'when',
#   'save',
#   'know',
#   'that',
#   'you',
#   'know',
#   'having',
#   'look',
#   'watch',
#   'know',
#   'know',
#   'know',
#   'gonna',
#   'that',
#   'labor',
#   'push',
#   'push',
#   'push',
#   'just',
#   'think',
#   'boom',
#   'wash',
#   'water',
#   'makin',
#   'change',
#   'know',
#   'about',
#   'get',
#   'know',
#   'know',
#   'you',
#   'you',
#   'owe',
#   'nipples',
#   'see',
#   'know',
#   'know',
#   'think',
#   'your'],
#  'for': ['coming',
#   'coming',
#   'been',
#   'turned',
#   'achieve',
#   'generation',
#   'fashion',
#   'warmth',
#   'marriage',
#   'them',
#   'the',
#   'weekend',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'and',
#   'fresh',
#   'but',
#   'when',
#   'them',
#   'his',
#   'the',
#   'once',
#   'the',
#   'that',
#   'all',
#   'the',
#   'when',
#   'mean',
#   'when',
#   'living',
#   'them',
#   'granted',
#   'while',
#   'reason',
#   'and',
#   'month',
#   'days',
#   'days',
#   'coming',
#   'the',
#   'playing',
#   'being',
#   'doing',
#   'receiving'],
#  'coming': ['hello', 'very', 'you', 'all', 'true'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'you',
#   'they',
#   'never',
#   'like',
#   'lot',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin',
#   'their',
#   'you',
#   'marked'],
#  'gonna': ['have',
#   'turn',
#   'die',
#   'overtake',
#   'have',
#   'trap',
#   'propose',
#   'stick',
#   'recognize',
#   'see',
#   'all',
#   'have',
#   'live',
#   'tell',
#   'happen',
#   'have',
#   'become',
#   'disappear',
#   'become',
#   'have',
#   'before',
#   'make',
#   'embarrassing',
#   'recycle',
#   'burn',
#   'and',
#   'poop',
#   'one'],
#  'have': ['get',
#   'pee',
#   'six',
#   'insomnia',
#   'take',
#   'their',
#   'hpv',
#   'yet',
#   'hpv',
#   'hpv',
#   'one',
#   'the',
#   'the',
#   'hoarding',
#   'hoarding',
#   'clean',
#   'lot',
#   'huge',
#   'these',
#   'done',
#   'been',
#   'any',
#   'many',
#   'earn',
#   'your',
#   'anal',
#   'because',
#   'executive',
#   'some',
#   'baby',
#   'kid',
#   'kid',
#   'had',
#   'children',
#   'any',
#   'kid',
#   'get',
#   'kid',
#   'sex',
#   'see',
#   'had',
#   'chip',
#   'the',
#   'good'],
#  'get': ['this',
#   'you',
#   'coming',
#   'rid',
#   'you',
#   'home',
#   'say',
#   'fancy',
#   'the',
#   'very',
#   'very',
#   'shit',
#   'work',
#   'shit',
#   'sicker',
#   'sicker',
#   'really',
#   'lot',
#   'lot',
#   'all',
#   'like',
#   'the',
#   'pregnant',
#   'pregnant',
#   'stage',
#   'into',
#   'older',
#   'old',
#   'little',
#   'pregnant',
#   'pregnant',
#   'that',
#   'blood',
#   'pregnant',
#   'huge',
#   'dark',
#   'big',
#   'big',
#   'all',
#   'pregnant'],
#  'this': ['shit',
#   'year',
#   'doctor',
#   'shit',
#   'shit',
#   'calculator',
#   'judy',
#   'and',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'the',
#   'restaurant',
#   'restaurant',
#   'hippy',
#   'sneaking',
#   'wacky',
#   'dude',
#   'dude',
#   'bitch',
#   'huge',
#   'shit',
#   'conversation',
#   'what',
#   'fucking',
#   'relatable',
#   'the',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'and',
#   'around',
#   'around',
#   'don',
#   'when',
#   'turning',
#   'husband',
#   'mexican',
#   'like',
#   'makes',
#   'outta',
#   'office',
#   'office',
#   'their',
#   'too',
#   'was',
#   'together',
#   'together',
#   'should',
#   'you',
#   'turns',
#   'annoying',
#   'they',
#   'you',
#   'out',
#   'that',
#   'over',
#   'work',
#   'the',
#   'around',
#   'anymore',
#   'that'],
#  'over': ['with', 'again', 'again', 'the', 'his'],
#  'with': ['cause',
#   'the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'white',
#   'white',
#   'white',
#   'somebody',
#   'jewish',
#   'glaucoma',
#   'our',
#   'this',
#   'husband',
#   'him',
#   'him',
#   'about',
#   'their',
#   'the',
#   'which',
#   'and',
#   'the',
#   'eyelashes',
#   'last',
#   'vietnam',
#   'male',
#   'your',
#   'kid',
#   'but',
#   'just',
#   'you',
#   'intention',
#   'god',
#   'your',
#   'hard',
#   'topics'],
#  'cause': ['have',
#   'straight',
#   'might',
#   'don',
#   'graduated',
#   'don',
#   'too',
#   'fingers',
#   'you',
#   'when',
#   'the',
#   'can',
#   'her',
#   'she',
#   'free',
#   'you',
#   'was',
#   'don'],
#  'pee': ['like', 'need', 'these'],
#  'like': ['ten',
#   'shit',
#   'have',
#   'fifty',
#   'the',
#   'and',
#   'this',
#   'the',
#   'you',
#   'but',
#   'god',
#   'god',
#   'all',
#   'had',
#   'hey',
#   'wassup',
#   'hey',
#   'where',
#   'the',
#   'just',
#   'you',
#   'date',
#   'you',
#   'voting',
#   'that',
#   'absorbing',
#   'could',
#   'you',
#   'hold',
#   'making',
#   'slip',
#   'did',
#   'loofah',
#   'responsibility',
#   'host',
#   'filipino',
#   'authentic',
#   'not',
#   'private',
#   'backpack',
#   'yoga',
#   'that',
#   'free',
#   'thousand',
#   'are',
#   'have',
#   'that',
#   'just',
#   'shut',
#   'god',
#   'you',
#   'very',
#   'dumb',
#   'could',
#   'but',
#   'look',
#   'that',
#   'you',
#   'wiping',
#   'courtney',
#   'been',
#   'you',
#   'hey',
#   'why',
#   'mrs',
#   'you',
#   'don',
#   'you',
#   'got',
#   'god',
#   'going',
#   'conqueror',
#   'that',
#   'that',
#   'discovered',
#   'you',
#   'yes',
#   'abused',
#   'don',
#   'become',
#   'certain',
#   'princess',
#   'guys',
#   'that',
#   'ali',
#   'yeah',
#   'why',
#   'yeah',
#   'turtle',
#   'yeah',
#   'god',
#   'just',
#   'the',
#   'only',
#   'skittles',
#   'smoker',
#   'everything',
#   'god',
#   'only',
#   'not',
#   'release',
#   'bunch',
#   'wouldn',
#   'time',
#   'they',
#   'hey',
#   'god',
#   'yeah',
#   'losing',
#   'and',
#   'yes',
#   'you',
#   'yeah',
#   'that',
#   'this',
#   'berate',
#   'daily',
#   'bullseye',
#   'fingers',
#   'you',
#   'whoppers',
#   'minion',
#   'when',
#   'really',
#   'why',
#   'way'],
#  'ten': ['minutes', 'gallons', 'times'],
#  'minutes': ['but'],
#  'but': ['thank',
#   'fuck',
#   'know',
#   'husband',
#   'did',
#   'think',
#   'grew',
#   'sometimes',
#   'ali',
#   'still',
#   'because',
#   'don',
#   'also',
#   'seven',
#   'still',
#   'body',
#   'what',
#   'the',
#   'mostly',
#   'not',
#   'different'],
#  'everybody': ['much',
#   'has',
#   'has',
#   'has',
#   'thought',
#   'doesn',
#   'thought',
#   'thank'],
#  'much': ['for',
#   'better',
#   'chemistry',
#   'don',
#   'shittier',
#   'netflix',
#   'for',
#   'resentment'],
#  'very': ['exciting',
#   'exciting',
#   'helpful',
#   'lucky',
#   'unusual',
#   'confusing',
#   'you',
#   'picturesque',
#   'you',
#   'underrated',
#   'well',
#   'surprised',
#   'soft',
#   'nurturing',
#   'domestic',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing',
#   'clinical',
#   'universal',
#   'grateful',
#   'common',
#   'early',
#   'much',
#   'very',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'let',
#   'yeah',
#   'and',
#   'was',
#   'getting',
#   'jobs',
#   'which',
#   'housewives',
#   'every',
#   'like',
#   'long',
#   'looks',
#   'this',
#   'since',
#   'long',
#   'redtube'],
#  'been': ['very',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'continue',
#   'run',
#   'eating',
#   'trying',
#   'ali'],
#  'year': ['for', 'yes', 'old', 'old', 'this', 'also', 'been', 'had', 'will'],
#  'turned': ['this'],
#  'yes': ['thank',
#   'yes',
#   'that',
#   'yes',
#   'yes',
#   'did',
#   'know',
#   'because',
#   'the'],
#  'five': ['people', 'years', 'years'],
#  'people': ['appreciate',
#   'inside',
#   'are',
#   'amazing',
#   'all',
#   'don',
#   'until',
#   'doing',
#   'like',
#   'are',
#   'was',
#   'that',
#   'were',
#   'praise',
#   'don',
#   'will'],
#  'appreciate': ['that'],
#  'that': ['can',
#   'getting',
#   'that',
#   'beautiful',
#   'huge',
#   'what',
#   'says',
#   'they',
#   'lives',
#   'have',
#   'gonna',
#   'getting',
#   'right',
#   'what',
#   'the',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'gonna',
#   'not',
#   'will',
#   'and',
#   'the',
#   'was',
#   'your',
#   'has',
#   'store',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement',
#   'for',
#   'you',
#   'where',
#   'right',
#   'eat',
#   'bread',
#   'tastes',
#   'lesbian',
#   'like',
#   'seems',
#   'seems',
#   'was',
#   'how',
#   'you',
#   'sent',
#   'told',
#   'how',
#   'that',
#   'become',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'see',
#   'fucking',
#   'housewife',
#   'bitch',
#   'horrible',
#   'they',
#   'one',
#   'office',
#   'they',
#   'not',
#   'your',
#   'the',
#   'unpredictable',
#   'shit',
#   'you',
#   'don',
#   'trapped',
#   'right',
#   'you',
#   'went',
#   'scared',
#   'gonna',
#   'and',
#   'gonna',
#   'you',
#   'you',
#   'then',
#   'they',
#   'fear',
#   'shit',
#   'fear',
#   'had',
#   'why',
#   'just',
#   'gonna',
#   'can',
#   'woman',
#   'now',
#   'whole',
#   'box',
#   'was',
#   'the',
#   'when',
#   'was',
#   'not',
#   'baby',
#   'hilarious',
#   'the',
#   'the',
#   'cool',
#   'everybody',
#   'what',
#   'came',
#   'she',
#   'not',
#   'cause',
#   'protect',
#   'you',
#   'snail',
#   'most',
#   'progesterone',
#   'were',
#   'made',
#   'all',
#   'hot',
#   'that',
#   'shit',
#   'tell',
#   'would',
#   'when',
#   'means',
#   'that',
#   'they',
#   'they',
#   'day',
#   'says',
#   'that',
#   'stupid',
#   'learned',
#   'harvard',
#   'right',
#   'they',
#   'dark',
#   'girl',
#   'like',
#   'lost',
#   'shit',
#   'miscarriage',
#   'why',
#   'you',
#   'white',
#   'blows',
#   'you',
#   'you',
#   'that',
#   'happens',
#   'enough',
#   'the',
#   'doesn',
#   'worthy',
#   'goes',
#   'didn',
#   'they',
#   'the',
#   'the',
#   'seven',
#   'not',
#   'beautiful',
#   'reflects'],
#  'can': ['tell',
#   'also',
#   'turn',
#   'turn',
#   'never',
#   'you',
#   'nice',
#   'tell',
#   'tell',
#   'never',
#   'listen',
#   'whatever',
#   'help',
#   'talk',
#   'talk',
#   'comfortably',
#   'tell',
#   'just',
#   'think',
#   'smell',
#   'smell',
#   'discretely',
#   'believe',
#   'wait',
#   'already',
#   'really',
#   'you',
#   'you',
#   'already',
#   'believe',
#   'see',
#   'find'],
#  'tell': ['that',
#   'that',
#   'first',
#   'the',
#   'you',
#   'them',
#   'get',
#   'you',
#   'you',
#   'but',
#   'you',
#   'because',
#   'you'],
#  'getting': ['older', 'older', 'busy', 'massages'],
#  'older': ['because', 'because', 'lonely', 'when'],
#  'because': ['now',
#   'year',
#   'undetectable',
#   'kindle',
#   'mom',
#   'you',
#   'what',
#   'according',
#   'before',
#   'knew',
#   'usually',
#   'being',
#   'half',
#   'asian',
#   'had',
#   'you',
#   'had',
#   'you',
#   'started',
#   'the',
#   'refused',
#   'you',
#   'they',
#   'control',
#   'the',
#   'her',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'asian',
#   'trying',
#   'only',
#   'when',
#   'they',
#   'they',
#   'then',
#   'the',
#   'hippies',
#   'last',
#   'when',
#   'the',
#   'really',
#   'leaves',
#   'body',
#   'went'],
#  'now': ['when',
#   'has',
#   'crush',
#   'for',
#   'expected',
#   'you',
#   'but',
#   'you',
#   'because',
#   'instead',
#   'and',
#   'that',
#   'don'],
#  'when': ['see',
#   'they',
#   'dictator',
#   'you',
#   'she',
#   'were',
#   'you',
#   'you',
#   'really',
#   'was',
#   'you',
#   'white',
#   'pee',
#   'you',
#   'hear',
#   'our',
#   'you',
#   'walk',
#   'hear',
#   'heard',
#   'said',
#   'got',
#   'you',
#   'puts',
#   'finally',
#   'that',
#   'when',
#   'asked',
#   'you',
#   'you',
#   'they',
#   'get',
#   'older',
#   'get',
#   'say',
#   'husband',
#   'you',
#   'trying',
#   'was',
#   'everything',
#   'wanna',
#   'can',
#   'can',
#   'can',
#   'husband',
#   'when',
#   'you',
#   'the',
#   'easter',
#   'was',
#   'they',
#   'would',
#   'somebody',
#   'somebody',
#   'was',
#   'man',
#   'they',
#   'they',
#   'you',
#   'they',
#   'told',
#   'told',
#   'they',
#   'you',
#   'you',
#   'asks',
#   'you',
#   'was',
#   'was',
#   'straight',
#   'neosporin'],
#  'see': ['year',
#   'ten',
#   'the',
#   'that',
#   'the',
#   'quarter',
#   'female',
#   'how',
#   'that',
#   'who',
#   'doctor',
#   'the',
#   'the',
#   'two',
#   'heartbeat',
#   'beyonc',
#   'how',
#   'how',
#   'not',
#   'like',
#   'year'],
#  'old': ['girl',
#   'girls',
#   'and',
#   'her',
#   'chinese',
#   'chinese',
#   'asian',
#   'and',
#   'when'],
#  'girl': ['automatic', 'because', 'when'],
#  'automatic': ['thought'],
#  'thought': ['fuck', 'was', 'they', 'was'],
#  'fuck': ['you',
#   'you',
#   'you',
#   'they',
#   'fine',
#   'down',
#   'one',
#   'they',
#   'him',
#   'and',
#   'wanted'],
#  'don': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'ever',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'for',
#   'got',
#   'wanna',
#   'straight',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'tell',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'try',
#   'your',
#   'wanna',
#   'wanna',
#   'worry',
#   'cheat',
#   'don',
#   'don',
#   'they',
#   'wanna',
#   'kill',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack',
#   'die',
#   'die',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'feel',
#   'tell',
#   'work'],
#  'even': ['know', 'know', 'accidentally', 'effective', 'have', 'come'],
#  'know': ['you',
#   'what',
#   'that',
#   'when',
#   'where',
#   'what',
#   'when',
#   'that',
#   'wear',
#   'what',
#   'because',
#   'you',
#   'white',
#   'hot',
#   'just',
#   'but',
#   'last',
#   'why',
#   'ooh',
#   'the',
#   'learning',
#   'anything',
#   'what',
#   'just',
#   'that',
#   'maybe',
#   'how',
#   'how',
#   'you',
#   'squeeze',
#   'very',
#   'that',
#   'freaked',
#   'was',
#   'and',
#   'especially',
#   'husband',
#   'respect',
#   'you',
#   'like',
#   'just',
#   'want',
#   'what',
#   'you',
#   'what',
#   'you',
#   'what',
#   'lot',
#   'another',
#   'the',
#   'why',
#   'what',
#   'need',
#   'not',
#   'what',
#   'and',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'like',
#   'your',
#   'that',
#   'that',
#   'they',
#   'and',
#   'previously'],
#  'straight': ['jealous', 'don', 'soldier'],
#  'jealous': ['jealous', 'first'],
#  'first': ['and',
#   'met',
#   'thing',
#   'dates',
#   'and',
#   'passively',
#   'you',
#   'lady',
#   'old',
#   'webmd',
#   'home'],
#  'foremost': ['their', 'the'],
#  'their': ['metabolism',
#   'feet',
#   'whole',
#   'house',
#   'communist',
#   'shit',
#   'doo',
#   'hallways',
#   'ipad',
#   'eyebrows',
#   'prostate',
#   'glasses',
#   'fame',
#   'existence',
#   'their',
#   'big',
#   'darth',
#   'arch',
#   'contest',
#   'eyes',
#   'eyes',
#   'eyes',
#   'head',
#   'eyelids',
#   'face',
#   'flip',
#   'husbands'],
#  'metabolism': ['because'],
#  'girls': ['they'],
#  'they': ['could',
#   'take',
#   'got',
#   'put',
#   'sleep',
#   'just',
#   'don',
#   'don',
#   'have',
#   'don',
#   'just',
#   'have',
#   'sexy',
#   'were',
#   'like',
#   'teach',
#   'introduce',
#   'the',
#   'got',
#   'just',
#   'get',
#   'mean',
#   'ruined',
#   'like',
#   'get',
#   'like',
#   'don',
#   'don',
#   'don',
#   'don',
#   'don',
#   'purposely',
#   'try',
#   'don',
#   'don',
#   'don',
#   'want',
#   'don',
#   'can',
#   'can',
#   'want',
#   'say',
#   'would',
#   'like',
#   'wax',
#   'all',
#   'get',
#   'scared',
#   'scared',
#   'like',
#   'gay',
#   'just',
#   'just',
#   'get',
#   'generally',
#   'have',
#   'get',
#   'like',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don',
#   'got',
#   'like',
#   'that',
#   'their',
#   'wear',
#   'can',
#   'just',
#   'make',
#   'watch',
#   'come',
#   'just',
#   'such',
#   'need',
#   'literally',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'like',
#   'wouldn',
#   'through',
#   'were',
#   'going',
#   'tried',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph',
#   'just',
#   'just',
#   'have',
#   'could',
#   'anything',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'sleep',
#   'cluttering',
#   'sleep',
#   'fucked',
#   'feel',
#   'right',
#   'and',
#   'crush',
#   'kill',
#   'like',
#   'black',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'let',
#   'put',
#   'felt',
#   'wanted',
#   'sneak',
#   'give',
#   'give',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'just',
#   'choke',
#   'waiting',
#   'keep',
#   'try',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'whatever',
#   'kidding',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'slime',
#   'scratch',
#   'vacuum',
#   'come',
#   'give',
#   'got',
#   'and',
#   'twerk',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like', 'gluten', 'all', 'that', 'you', 'snacks', 'sad', 'bananas'],
#  'then': ['they',
#   'when',
#   'after',
#   'also',
#   'asian',
#   'doesn',
#   'afterwards',
#   'all',
#   'backfired',
#   'had',
#   'you',
#   'you',
#   'your',
#   'you',
#   'might',
#   'you',
#   'the',
#   'had',
#   'writing',
#   'some',
#   'side',
#   'had',
#   'resist',
#   'doesn',
#   'when',
#   'because',
#   'would',
#   'would',
#   'she',
#   'you',
#   'meet',
#   'got',
#   'got'],
#  'take': ['shit', 'ambien', 'these', 'stroll', 'these', 'its'],
#  'six': ['pack', 'week'],
#  'pack': ['right'],
#  'right': ['they',
#   'they',
#   'that',
#   'basically',
#   'how',
#   'ali',
#   'there',
#   'now',
#   'pay',
#   'because',
#   'and',
#   'you',
#   'like',
#   'moment',
#   'turn',
#   'cause',
#   'there',
#   'after',
#   'been'],
#  'got': ['that',
#   'emotional',
#   'married',
#   'body',
#   'number',
#   'the',
#   'engaged',
#   'women',
#   'married',
#   'married',
#   'second',
#   'married',
#   'century',
#   'shame',
#   'bit',
#   'him',
#   'him',
#   'married',
#   'pregnant'],
#  'beautiful': ['inner', 'harvard'],
#  'inner': ['thigh', 'peace', 'evil'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they',
#   'body',
#   'how',
#   'the',
#   'was',
#   'the',
#   'can',
#   'they',
#   'from',
#   'nude',
#   'holds'],
#  'put': ['their', 'the', 'her', 'different'],
#  'feet': ['together'],
#  'together': ['and', 'you', 'now', 'they', 'make', 'when', 'father', 'and'],
#  'there': ['that',
#   'and',
#   'through',
#   'like',
#   'and',
#   'when',
#   'and',
#   'ban',
#   'none',
#   'this',
#   'multiple',
#   'for',
#   'for',
#   'would',
#   'can',
#   'like',
#   'nothing',
#   'but'],
#  'huge': ['gap', 'unspoken', 'sit', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'too', 'you'],
#  'light': ['potential', 'completely'],
#  'potential': ['just', 'why'],
#  'radiating': ['through'],
#  'through': ['and', 'the', 'southeast', 'and', 'full', 'when', 'miscarriage'],
#  'sleep': ['they', 'right', 'peace'],
#  'insomnia': ['yet'],
#  'yet': ['they', 'they', 'you', 'you', 'and'],
#  'what': ['like',
#   'that',
#   'your',
#   'that',
#   'could',
#   'wrong',
#   'love',
#   'the',
#   'really',
#   'happens',
#   'you',
#   'does',
#   'and',
#   'talking',
#   'else',
#   'gonna',
#   'everybody',
#   'wrong',
#   'kind',
#   'crackin',
#   'that',
#   'don',
#   'that',
#   'doula'],
#  'ambien': ['download'],
#  'download': ['meditation'],
#  'meditation': ['oasis', 'retreats'],
#  'oasis': ['podcast'],
#  'podcast': ['calm'],
#  'calm': ['the'],
#  'chatter': ['regret'],
#  'regret': ['and'],
#  'resentment': ['towards', 'especially'],
#  'towards': ['your', 'husband', 'him'],
#  'your': ['family',
#   'mind',
#   'all',
#   'wealth',
#   'butt',
#   'mom',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'worker',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame',
#   'inner',
#   'secrets',
#   'just',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers',
#   'fingers',
#   'first',
#   'when',
#   'and',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg',
#   'life',
#   'doctor',
#   'body',
#   'nipples',
#   'email'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind': ['they', 'turn', 'again'],
#  'whole': ['lives', 'manipulation', 'new', 'foods', 'foods', 'thing'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['them'],
#  'them': ['they', 'they', 'the', 'nothing', 'once', 'they', 'myself'],
#  'hpv': ['yet',
#   'everybody',
#   'yet',
#   'because',
#   'ghost',
#   'either',
#   'will',
#   'very'],
#  'peace': ['night', 'and', 'sign'],
#  'night': ['everybody', 'you', 'and', 'everybody'],
#  'has': ['hpv',
#   'come',
#   'you',
#   'hpv',
#   'hosted',
#   'even',
#   'made',
#   'incept',
#   'pinterest',
#   'had',
#   'those'],
#  'come': ['out', 'handy', 'out', 'and', 'out', 'out', 'home', 'with', 'out'],
#  'out': ['already',
#   'can',
#   'league',
#   'there',
#   'the',
#   'they',
#   'and',
#   'they',
#   'slow',
#   'about',
#   'down',
#   'control',
#   'control',
#   'nowhere',
#   'first',
#   'that',
#   'the',
#   'like',
#   'like',
#   'their',
#   'him',
#   'when',
#   'six',
#   'they',
#   'about',
#   'and',
#   'yet',
#   'survival',
#   'league',
#   'the'],
#  'already': ['everybody', 'see', 'resentful', 'see'],
#  'fucking': ['loser', 'housewife', 'different', 'baby', 'baby'],
#  'loser': ['all'],
#  'all': ['right',
#   'about',
#   'other',
#   'your',
#   'came',
#   'required',
#   'because',
#   'this',
#   'right',
#   'his',
#   'that',
#   'that',
#   'the',
#   'bed',
#   'fucked',
#   'red',
#   'you',
#   'that',
#   'this',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'your',
#   'your',
#   'thinking',
#   'squirmy',
#   'right',
#   'the',
#   'the',
#   'asian',
#   'these',
#   'sudden',
#   'know',
#   'her',
#   'the',
#   'the',
#   'day',
#   'you',
#   'good',
#   'that',
#   'the',
#   'backed',
#   'doctor',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'dreams',
#   'off',
#   'right',
#   'rights'],
#  'says': ['about', 'boo', 'please', 'god'],
#  'about': ['you',
#   'how',
#   'the',
#   'him',
#   'lot',
#   'vietnamese',
#   'yelp',
#   'supporting',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'eat',
#   'the',
#   'money',
#   'anal',
#   'just',
#   'talking',
#   'that',
#   'when',
#   'finish',
#   'finish',
#   'they',
#   'giving',
#   'childbirth',
#   'all',
#   'kanye',
#   'growing'],
#  'lot': ['men',
#   'this',
#   'losers',
#   'skaters',
#   'people',
#   'opinions',
#   'cool',
#   'women',
#   'options',
#   'friends',
#   'love',
#   'more',
#   'myself',
#   'women',
#   'resistance',
#   'please',
#   'female',
#   'more',
#   'friends',
#   'that',
#   'people',
#   'fuckin',
#   'women',
#   'women'],
#  'men': ['don', 'really', 'bodies', 'are', 'are', 'body', 'got', 'possible'],
#  'undetectable': ['men'],
#  'really': ['fucked',
#   'the',
#   'public',
#   'work',
#   'meant',
#   'you',
#   'scared',
#   'don',
#   'imma',
#   'take',
#   'mad',
#   'hot'],
#  'fucked': ['hpv', 'homeless', 'afterwards', 'have'],
#  'ghost': ['that'],
#  'inside': ['men', 'horrible', 'thought', 'that'],
#  'bodies': ['and', 'doctor'],
#  'boo': ['women'],
#  'women': ['bodies',
#   'who',
#   'intuition',
#   'all',
#   'should',
#   'our',
#   'don',
#   'had',
#   'get',
#   'get',
#   'they',
#   'who',
#   'who',
#   'live',
#   'who',
#   'who',
#   'would',
#   'won',
#   'tried'],
#  'doctor': ['told',
#   'right',
#   'your',
#   'says',
#   'appointments',
#   'appointments',
#   'appointments'],
#  'told': ['that', 'her', 'you', 'mom', 'her'],
#  'one': ['two',
#   'our',
#   'the',
#   'ply',
#   'workers',
#   'person',
#   'dare',
#   'those',
#   'she',
#   'those',
#   'who'],
#  'two': ['strains', 'homeless', 'days', 'latina', 'sacks', 'weeks'],
#  'strains': ['hpv'],
#  'either': ['have', 'gonna'],
#  'kind': ['that', 'where', 'privileged', 'income', 'mother', 'body'],
#  'turn': ['into',
#   'this',
#   'this',
#   'into',
#   'signal',
#   'changed',
#   'changed',
#   'every',
#   'upside'],
#  'into': ['cervical',
#   'self',
#   'the',
#   'yoko',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'circle',
#   'pleasure',
#   'car',
#   'underwear',
#   'your',
#   'soft',
#   'the'],
#  'cervical': ['cancer'],
#  'cancer': ['have'],
#  'body': ['will',
#   'secret',
#   'hair',
#   'all',
#   'odor',
#   'was',
#   'when',
#   'where',
#   'secreting'],
#  'will': ['heal',
#   'also',
#   'also',
#   'you',
#   'always',
#   'asked',
#   'have',
#   'commend',
#   'not'],
#  'heal': ['itself', 'from'],
#  'itself': ['very'],
#  'helpful': ['this'],
#  'basically': ['either', 'just', 'like'],
#  'die': ['you', 'and', 'don', 'but', 'don', 'especially', 'like', 'why'],
#  'presence': ['wolverine'],
#  'wolverine': ['bitches'],
#  'bitches': ['find', 'get'],
#  'find': ['out', 'new', 'ways', 'way', 'easier'],
#  'also': ['tell',
#   'disappear',
#   'got',
#   'last',
#   'vulnerable',
#   'don',
#   'decided',
#   'takes'],
#  'kindle': ['turning'],
#  'turning': ['into', 'into'],
#  'self': ['help', 'esteem'],
#  'help': ['library', 'tony', 'have', 'her', 'you', 'many'],
#  'library': ['not'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic',
#   'recognize',
#   'doing',
#   'housewife',
#   'even',
#   'have',
#   'part',
#   'dieting',
#   'scared',
#   'freaky',
#   'the',
#   'again',
#   'rush',
#   'trying',
#   'destiny',
#   'technically',
#   'wet',
#   'and',
#   'fuckin',
#   'because',
#   'doing',
#   'there',
#   'gonna',
#   'like',
#   'the',
#   'published'],
#  'interested': ['books', 'the'],
#  'books': ['like'],
#  'fifty': ['shades'],
#  'shades': ['grey'],
#  'grey': ['interested'],
#  'life': ['changing', 'was', 'chose', 'you', 'crisis', 'not', 'and', 'right'],
#  'changing': ['magic'],
#  'magic': ['tidying'],
#  'tidying': ['yes'],
#  'how': ['declutter',
#   'can',
#   'can',
#   'proposals',
#   'did',
#   'rotten',
#   'off',
#   'women',
#   'anything',
#   'much',
#   'invincible',
#   'child',
#   'there',
#   'takes',
#   'did',
#   'did'],
#  'declutter': ['home'],
#  'home': ['achieve',
#   'san',
#   'and',
#   'all',
#   'and',
#   'chapping',
#   'mom',
#   'and',
#   'together'],
#  'achieve': ['inner', 'optimum'],
#  'optimum': ['level', 'level'],
#  'level': ['success', 'success'],
#  'success': ['that', 'grew'],
#  'around': ['horrible',
#   'help',
#   'together',
#   'all',
#   'they',
#   'support',
#   'the',
#   'keeping'],
#  'horrible': ['person', 'but', 'toilet'],
#  'person': ['not', 'you', 'for'],
#  'happy': ['with'],
#  'tony': ['robbins'],
#  'robbins': ['help'],
#  'hoarding': ['problem', 'goes', 'problem'],
#  'problem': ['which', 'because'],
#  'which': ['hoping',
#   'very',
#   'lot',
#   'means',
#   'would',
#   'great',
#   'means',
#   'their',
#   'turn',
#   'very',
#   'definitely',
#   'know',
#   'fine',
#   'very',
#   'very',
#   'means',
#   'subsequently'],
#  'hoping': ['the', 'that'],
#  'center': ['all'],
#  'other': ['problems', 'homeless', 'because', 'day', 'you', 'shitty'],
#  'problems': ['hoping'],
#  'goes': ['away', 'down'],
#  'away': ['the', 'anything', 'from', 'lot', 'his'],
#  'disappear': ['have', 'that', 'and'],
#  'mom': ['from', 'was', 'got', 'dad', 'home', 'was', 'going', 'she', 'people'],
#  'from': ['third',
#   'the',
#   'the',
#   'the',
#   'the',
#   'think',
#   'pier',
#   'harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'third',
#   'that',
#   'holding',
#   'bacteria',
#   'harvard',
#   'tight',
#   'the'],
#  'third': ['world', 'grade', 'world'],
#  'world': ['country', 'was', 'with', 'country'],
#  'country': ['and', 'and', 'and'],
#  'she': ['taught',
#   'refused',
#   'don',
#   'was',
#   'the',
#   'wrote',
#   'not',
#   'retired',
#   'waiting',
#   'timing',
#   'busy',
#   'knows',
#   'got',
#   'lonely',
#   'doesn',
#   'from',
#   'was',
#   'said'],
#  'taught': ['that'],
#  'never': ['throw',
#   'know',
#   'know',
#   'finish',
#   'finish',
#   'called',
#   'paintballing',
#   'behave'],
#  'throw': ['away', 'lot', 'the'],
#  'anything': ['because', 'about', 'guess', 'bitch', 'look'],
#  'dictator': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth': ['you'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'you', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade': ['cause', 'cost'],
#  'might': ['come', 'need', 'mean'],
#  'handy': ['shovel'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'the', 'don', 'makin'],
#  'stuffing': ['gold'],
#  'gold': ['your'],
#  'butt': ['and', 'hole', 'with', 'hole', 'cheeks', 'all', 'gotta', 'hole'],
#  'running': ['away'],
#  'communists': ['the'],
#  'last': ['time', 'forever', 'boyfriend', 'time', 'year', 'boyfriend', 'year'],
#  'time': ['was',
#   'and',
#   'was',
#   'shitting',
#   'and',
#   'date',
#   'was',
#   'whole',
#   'that',
#   'the',
#   'get',
#   'all',
#   'you',
#   'you',
#   'and',
#   'was',
#   'like',
#   'and',
#   'and'],
#  'was': ['home',
#   'trying',
#   'like',
#   'emotional',
#   'this',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'that',
#   'attending',
#   'like',
#   'catch',
#   'like',
#   'living',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'cuban',
#   'like',
#   'like',
#   'like',
#   'legit',
#   'gonna',
#   'ready',
#   'ripe',
#   'rotten',
#   'people',
#   'free',
#   'like',
#   'you',
#   'like',
#   'like',
#   'done',
#   'like',
#   'very',
#   'like',
#   'magical',
#   'help',
#   'sliced',
#   'sliced',
#   'like',
#   'like',
#   'gonna',
#   'starting',
#   'just',
#   'juicy',
#   'ate',
#   'when',
#   'clearly',
#   'that',
#   'easter',
#   'like',
#   'tired',
#   'about',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'years',
#   'like',
#   'like',
#   'debt'],
#  'san': ['francisco', 'francisco'],
#  'francisco': ['was', 'when'],
#  'trying': ['help',
#   'procrastinator',
#   'die',
#   'one',
#   'get',
#   'have',
#   'get',
#   'shut'],
#  'her': ['get',
#   'send',
#   'book',
#   'lululemon',
#   'butt',
#   'there',
#   'sexist',
#   'nipples',
#   'pussy',
#   'white',
#   'mexican',
#   'and',
#   'had',
#   'generation'],
#  'rid': ['shit'],
#  'ever': ['that', 'actually', 'happened'],
#  'worst': ['experience', 'thing'],
#  'experience': ['life', 'some'],
#  'emotional': ['were', 'about'],
#  'were': ['screaming',
#   'all',
#   'eight',
#   'hipsters',
#   'getting',
#   'done',
#   'like',
#   'discouraging',
#   'like',
#   'years',
#   'alarmingly',
#   'suppositories',
#   'trying',
#   'like',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['climax', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['let', 'put'],
#  'let': ['texas', 'two', 'tell', 'echo', 'redecorate', 'see', 'their'],
#  'texas': ['instruments'],
#  'instruments': ['manual'],
#  'manual': ['the', 'she', 'and'],
#  'calculator': ['those', 'was', 'that'],
#  'those': ['you', 'brains', 'comments', 'green', 'old', 'doctor', 'crazy'],
#  'under': ['probably'],
#  'probably': ['don', 'pinterested', 'one', 'looked'],
#  'bamboozled': ['generation'],
#  'generation': ['were', 'you', 'features'],
#  'required': ['buy', 'fields'],
#  'buy': ['when'],
#  'eight': ['grade'],
#  'cost': ['like'],
#  'judy': ['jetson'],
#  'jetson': ['laptop'],
#  'laptop': ['from'],
#  'future': ['all', 'cause'],
#  'graph': ['was'],
#  'tesla': ['time'],
#  'need': ['this',
#   'see',
#   'leave',
#   'made',
#   'get',
#   'eat',
#   'make',
#   'abuse',
#   'hide',
#   'have',
#   'children',
#   'see',
#   'you',
#   'close'],
#  'clean': ['all'],
#  'procrastinator': ['anymore'],
#  'anymore': ['because',
#   'don',
#   'don',
#   'been',
#   'holds',
#   'and',
#   'since',
#   'not',
#   'very',
#   'busy'],
#  'according': ['deepak', 'her'],
#  'deepak': ['oprah'],
#  'oprah': ['that'],
#  'way': ['for', 'out', 'saying', 'smell', 'more'],
#  'grew': ['lot', 'the', 'like', 'going'],
#  'past': ['year', 'year'],
#  'married': ['yeah', 'last', 'disgusting', 'you', 'was', 'all'],
#  'yeah': ['man',
#   'you',
#   'yes',
#   'which',
#   'like',
#   'never',
#   'very',
#   'that',
#   'that',
#   'let',
#   'and',
#   'where',
#   'look'],
#  'man': ['who',
#   'could',
#   'head',
#   'and',
#   'has',
#   'little',
#   'first',
#   'eye',
#   'all',
#   'about',
#   'needs'],
#  'who': ['now',
#   'that',
#   'like',
#   'like',
#   'are',
#   'wrote',
#   'are',
#   'have',
#   'recycles',
#   'gonna',
#   'are',
#   'have',
#   'else',
#   'tries',
#   'like',
#   'trapped'],
#  'lucky': ['guy', 'girl'],
#  'guy': ['gave', 'broad', 'who'],
#  'gave': ['something', 'him', 'lot'],
#  'something': ['gave', 'that', 'and', 'that', 'man'],
#  'him': ['something',
#   'dated',
#   'this',
#   'and',
#   'was',
#   'until',
#   'off',
#   'run',
#   'and',
#   'and',
#   'you',
#   'until',
#   'every',
#   'with',
#   'very',
#   'out',
#   'the',
#   'little',
#   'that',
#   'spank',
#   'when',
#   'and',
#   'and',
#   'whatever',
#   'for',
#   'finally',
#   'but',
#   'down',
#   'around',
#   'down',
#   'propose',
#   'and'],
#  'forever': ['really', 'and'],
#  'before': ['him', 'got', 'ladies', 'because', 'met'],
#  'dated': ['lot', 'bunch'],
#  'losers': ['lots', 'lot', 'and'],
#  'lots': ['losers'],
#  'skaters': ['you', 'stop', 'unless'],
#  'wanna': ['grown',
#   'wake',
#   'work',
#   'work',
#   'work',
#   'lean',
#   'lie',
#   'throw',
#   'talk',
#   'provide',
#   'work',
#   'that',
#   'roughed',
#   'experience',
#   'die',
#   'die',
#   'out',
#   'get',
#   'able',
#   'smell',
#   'work'],
#  'grown': ['ass'],
#  'ass': ['woman',
#   'going',
#   'and',
#   'initially',
#   'meal',
#   'into',
#   'into',
#   'into',
#   'stiviano',
#   'look',
#   'got',
#   'and'],
#  'woman': ['stop', 'has', 'always', 'his', 'wants', 'who', 'and', 'affection'],
#  'stop': ['dating', 'dating'],
#  'dating': ['skaters', 'skaters', 'for'],
#  'unless': ['you'],
#  'wake': ['mattress'],
#  'mattress': ['kitchen'],
#  'kitchen': ['they'],
#  'sexy': ['the'],
#  'outside': ['malt', 'that'],
#  'malt': ['liquor'],
#  'liquor': ['the'],
#  'husband': ['first',
#   'asian',
#   'half',
#   'and',
#   'completely',
#   'recently',
#   'unfortunately',
#   'get',
#   'and',
#   'dies',
#   'isn',
#   'and',
#   'hand',
#   'down',
#   'will',
#   'much',
#   'for',
#   'like',
#   'had',
#   'was'],
#  'met': ['him', 'and', 'husband'],
#  'wedding': ['and', 'dress'],
#  'looking': ['than'],
#  'than': ['way', 'when', 'discouraged', 'the', 'out'],
#  'league': ['and', 'graduated'],
#  'saw': ['him', 'this', 'pinterest', 'those', 'earlier'],
#  'god': ['who',
#   'gonna',
#   'just',
#   'smooth',
#   'proposed',
#   'like',
#   'and',
#   'not',
#   'was',
#   'that',
#   'that',
#   'see',
#   'can',
#   'then'],
#  'thing': ['learned', 'knew', 'that', 'which', 'lot', 'and'],
#  'learned': ['about', 'atlanta'],
#  'attending': ['harvard'],
#  'harvard': ['business',
#   'business',
#   'nectar',
#   'business',
#   'educated',
#   'business'],
#  'business': ['school', 'school', 'school', 'school'],
#  'school': ['and', 'playing', 'too', 'asians', 'and', 'worked', 'the'],
#  'trap': ['his', 'his', 'won', 'his'],
#  'his': ['ass',
#   'ass',
#   'ass',
#   'other',
#   'family',
#   'lunch',
#   'earning',
#   'butt',
#   'eyes',
#   'eyes',
#   'neck',
#   'head',
#   'self',
#   'ass',
#   'prestigious',
#   'comedy',
#   'rise'],
#  'going': ['trap', 'private', 'private', 'back', 'through', 'through', 'hire'],
#  'trapped': ['his', 'your', 'how'],
#  'initially': ['not'],
#  'kissing': ['him'],
#  'until': ['the', 'met', 'becomes', 'husband', 'billion'],
#  'fifth': ['date'],
#  'date': ['which', 'white', 'more', 'thanks'],
#  'unusual': ['move', 'see'],
#  'move': ['part'],
#  'part': ['but', 'this'],
#  'did': ['purpose',
#   'not',
#   'know',
#   'that',
#   'anal',
#   'have',
#   'you',
#   'how',
#   'bamboozle'],
#  'purpose': ['because'],
#  'knew': ['that', 'were'],
#  'catch': ['was', 'you'],
#  'gotta': ['make',
#   'explain',
#   'threaten',
#   'work',
#   'shit',
#   'shit',
#   'use',
#   'ten',
#   'that',
#   'use',
#   'muffle',
#   'worry',
#   'try',
#   'take',
#   'call',
#   'change',
#   'change',
#   'keep',
#   'check',
#   'stay',
#   'keep'],
#  'make': ['this',
#   'difficult',
#   'macgyver',
#   'sure',
#   'lot',
#   'this',
#   'right',
#   'sandwich',
#   'sure',
#   'him'],
#  'dude': ['believe',
#   'again',
#   'you',
#   'you',
#   'mean',
#   'eats',
#   'and',
#   'focus',
#   'and',
#   'you',
#   'named',
#   'that'],
#  'believe': ['that', 'that', 'comes', 'that'],
#  'secret': ['garden', 'they'],
#  'garden': ['when'],
#  'public': ['park'],
#  'park': ['that', 'and', 'and', 'this'],
#  'hosted': ['many'],
#  'many': ['reggae', 'more', 'men'],
#  'reggae': ['fests'],
#  'fests': ['and'],
#  'accidentally': ['let'],
#  'homeless': ['people', 'you', 'friends', 'dude'],
#  'hipsters': ['that'],
#  'store': ['urban'],
#  'urban': ['outfitters'],
#  'outfitters': ['has'],
#  'made': ['things', 'into', 'when', 'extremely', 'you'],
#  'things': ['very', 'like'],
#  'confusing': ['for'],
#  'hipster': ['that', 'neighborhood'],
#  'beard': ['for'],
#  'fashion': ['for'],
#  'warmth': ['happened'],
#  'happened': ['happened', 'san', 'women'],
#  'living': ['there', 'that'],
#  'broad': ['daylight'],
#  'daylight': ['and'],
#  'had': ['like',
#   'had',
#   'much',
#   'been',
#   'this',
#   'been',
#   'this',
#   'tried',
#   'good',
#   'show',
#   'lot',
#   'start',
#   'the',
#   'this',
#   'was',
#   'magical',
#   'such',
#   'this',
#   'alert',
#   'take',
#   'act',
#   'find',
#   'miscarriage',
#   'miscarriage',
#   'one',
#   'the',
#   'dated'],
#  'chemistry': ['was'],
#  'hey': ['wassup', 'can', 'wanna', 'hey', 'are', 'hey', 'please', 'can'],
#  'wassup': ['was', 'and'],
#  'next': ['thing', 'century'],
#  'back': ['volvo', 'out', 'was', 'time', 'their', 'shape'],
#  'volvo': ['and'],
#  'after': ['were', 'they'],
#  'done': ['was', 'the', 'done', 'don', 'before'],
#  'drop': ['off'],
#  'off': ['was', 'golden', 'stage', 'and', 'the', 'the', 'craigslist', 'turns'],
#  'dropped': ['him'],
#  'golden': ['gate'],
#  'gate': ['park'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends': ['and', 'when', 'who', 'said', 'dead', 'dead', 'dead', 'life'],
#  'again': ['husband', 'you', 'and', 'turn', 'need', 'but', 'because'],
#  'asian': ['which',
#   'american',
#   'american',
#   'men',
#   'men',
#   'and',
#   'yeah',
#   'too',
#   'people',
#   'female',
#   'american',
#   'woman',
#   'don',
#   'ladies'],
#  'shocked': ['because'],
#  'usually': ['asian'],
#  'american': ['women', 'men', 'brothers'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches',
#   'chinese',
#   'women',
#   'boring',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and', 'always'],
#  'opinions': ['they'],
#  'white': ['dudes',
#   'dude',
#   'dude',
#   'dudes',
#   'dude',
#   'dude',
#   'man',
#   'people',
#   'people',
#   'friends',
#   'hippie',
#   'collar'],
#  'dudes': ['you', 'they'],
#  'any': ['hipster', 'moment', 'real', 'sort', 'black', 'given'],
#  'neighborhood': ['major'],
#  'major': ['city'],
#  'city': ['america'],
#  'america': ['and'],
#  'yoko': ['ono'],
#  'ono': ['factory'],
#  'factory': ['too'],
#  'too': ['much',
#   'nice',
#   'him',
#   'like',
#   'but',
#   'old',
#   'late',
#   'stupid',
#   'they',
#   'funky'],
#  'wrong': ['with', 'with'],
#  'being': ['with', 'the', 'courageous'],
#  'feel': ['very',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'bad',
#   'bad'],
#  'picturesque': ['when'],
#  'wes': ['anderson'],
#  'anderson': ['movie'],
#  'movie': ['something', 'need'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff', 'until'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling': ['and'],
#  'disturbing': ['documentaries'],
#  'documentaries': ['they'],
#  'introduce': ['you'],
#  'hot': ['hookin', 'you', 'you'],
#  'hookin': ['with'],
#  'mean': ['nothing', 'like', 'that', 'pay'],
#  'nothing': ['makes', 'they', 'for'],
#  'makes': ['feel', 'feel', 'sense'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'and',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['pussy'],
#  'pussy': ['god', 'needs', 'not', 'was', 'keyser', 'all', 'all'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement': ['you'],
#  'money': ['hole', 'they', 'you', 'you', 'you', 'paid'],
#  'hole': ['and', 'basically', 'feels', 'and'],
#  'vulnerable': ['down'],
#  'down': ['there',
#   'like',
#   'want',
#   'think',
#   'with',
#   'there',
#   'your',
#   'immediately',
#   'front',
#   'that',
#   'people',
#   'with'],
#  'crush': ['your', 'those', 'while'],
#  'head': ['any', 'first', 'shredding', 'and', 'for'],
#  'moment': ['white', 'like', 'you'],
#  'kill': ['you', 'don'],
#  'brains': ['colonize'],
#  'colonize': ['the'],
#  'colonizer': ['you'],
#  'think': ['that',
#   'husband',
#   'feminism',
#   'had',
#   'because',
#   'one',
#   'about',
#   'that',
#   'you',
#   'performing'],
#  'marriage': ['can', 'always', 'because'],
#  'nice': ['with', 'need'],
#  'somebody': ['your', 'closes', 'closes'],
#  'own': ['race', 'goddamn'],
#  'race': ['the'],
#  'advantage': ['that'],
#  'racist': ['together'],
#  'say': ['whatever', 'anymore', 'you', 'you', 'there'],
#  'whatever': ['you', 'and', 'they', 'you', 'the'],
#  'explain': ['shit'],
#  'half': ['filipino',
#   'japanese',
#   'chinese',
#   'vietnamese',
#   'filipino',
#   'japanese',
#   'chinese',
#   'vietnamese',
#   'fancy',
#   'jungle',
#   'months',
#   'months',
#   'months',
#   'months'],
#  'filipino': ['half', 'and', 'carlton'],
#  'japanese': ['half', 'and', 'they'],
#  'chinese': ['and', 'and', 'the', 'scrolls', 'ladies', 'ladies'],
#  'vietnamese': ['and', 'both', 'people', 'read'],
#  'spend': ['percent'],
#  'percent': ['our', 'your', 'spoken'],
#  'our': ['time',
#   'first',
#   'buddha',
#   'careers',
#   'job',
#   'day',
#   'society',
#   'first'],
#  'shitting': ['korean'],
#  'korean': ['people'],
#  'amazing': ['what'],
#  'love': ['built', 'dolphin', 'lot', 'workers', 'very', 'your'],
#  'built': ['you'],
#  'boyfriend': ['was', 'because'],
#  'cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'choose',
#   'crash',
#   'simultaneously',
#   'explode',
#   'that',
#   'storyboarding',
#   'inevitably',
#   'only',
#   'like',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'mexican': ['people', 'asian', 'friends'],
#  'guys': ['aren', 'know', 'about', 'need', 'had', 'can', 'just', 'doin'],
#  'aren': ['mexican'],
#  'underrated': ['don'],
#  'why': ['people',
#   'you',
#   'else',
#   'you',
#   'are',
#   'are',
#   'don',
#   'such',
#   'going',
#   'different',
#   'else',
#   'artists',
#   'every'],
#  'sexiest': ['asian', 'they'],
#  'hair': ['from'],
#  'neck': ['down', 'and'],
#  'making': ['love'],
#  'dolphin': ['god'],
#  'smooth': ['just'],
#  'slip': ['and'],
#  'slide': ['just'],
#  'black': ['fish', 'don', 'friends', 'friends'],
#  'fish': ['tilikum'],
#  'tilikum': ['all'],
#  'bed': ['every', 'women'],
#  'every': ['night',
#   'day',
#   'single',
#   'day',
#   'day',
#   'day',
#   'day',
#   'time',
#   'single',
#   'time',
#   'man'],
#  'ooh': ['wee'],
#  'wee': ['you'],
#  'mess': ['with', 'there'],
#  'jewish': ['dude', 'male'],
#  'afterwards': ['all', 'the', 'and', 'and', 'want', 'make'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['exfoliated', 'for'],
#  'exfoliated': ['today'],
#  'today': ['this'],
#  'loofah': ['date'],
#  'thanks': ['for'],
#  'rug': ['burn'],
#  'burn': ['avi', 'out'],
#  'avi': ['and'],
#  'odor': ['none'],
#  'none': ['they', 'them'],
#  'smell': ['like',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers',
#   'fingers',
#   'fingers'],
#  'responsibility': ['that', 'and'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from', 'out', 'out', 'out', 'all'],
#  'unspoken': ['understanding'],
#  'understanding': ['between'],
#  'between': ['each', 'your'],
#  'each': ['other', 'other'],
#  'both': ['half', 'total', 'are'],
#  'fancy': ['asian', 'asians', 'things'],
#  'jungle': ['asian', 'asians'],
#  'difference': ['the'],
#  'asians': ['are', 'host', 'both'],
#  'host': ['olympics', 'diseases'],
#  'olympics': ['jungle'],
#  'diseases': ['different'],
#  'different': ['but', 'person', 'holes', 'people', 'not', 'and'],
#  'east': ['coast'],
#  'coast': ['going'],
#  'private': ['school', 'school', 'school'],
#  'playing': ['lacrosse', 'chess', 'dumb', 'candy'],
#  'lacrosse': ['you'],
#  'learning': ['latin'],
#  'latin': ['and'],
#  'chess': ['and'],
#  'rugby': ['grew'],
#  'carlton': ['didn'],
#  'didn': ['know', 'think', 'know', 'know'],
#  'dates': ['took'],
#  'took': ['this', 'for', 'see'],
#  'restaurant': ['the', 'deaf'],
#  'west': ['side', 'the'],
#  'side': ['los', 'from', 'effect'],
#  'los': ['angeles', 'angeles'],
#  'angeles': ['called', 'attempt'],
#  'called': ['pho', 'lean', 'bossy'],
#  'pho': ['show'],
#  'show': ['was', 'off', 'love', 'him', 'signs', 'there'],
#  'authentic': ['vietnamese', 'you'],
#  'read': ['about'],
#  'yelp': ['was'],
#  'name': ['cause', 'mail'],
#  'number': ['second'],
#  'second': ['all', 'chance'],
#  'bathroom': ['was', 'would'],
#  'legit': ['the'],
#  'double': ['supply', 'income', 'standard'],
#  'supply': ['closet'],
#  'closet': ['when'],
#  'gallons': ['bleach'],
#  'bleach': ['atm'],
#  'atm': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with', 'you'],
#  'glaucoma': ['napping'],
#  'napping': ['the'],
#  'corner': ['and'],
#  'wait': ['staff', 'cleanse'],
#  'staff': ['here', 'and'],
#  'leave': ['this', 'without', 'you'],
#  'deaf': ['and'],
#  'emotionally': ['abused'],
#  'abused': ['grew', 'the'],
#  'total': ['like'],
#  'big': ['hippies', 'fantasy', 'impact', 'ass', 'they', 'like'],
#  'hippies': ['too', 'like'],
#  'backpack': ['through'],
#  'southeast': ['asia'],
#  'asia': ['like'],
#  'yoga': ['ayahuasca'],
#  'ayahuasca': ['ceremonies'],
#  'ceremonies': ['silent'],
#  'silent': ['meditation'],
#  'retreats': ['that'],
#  'pay': ['shut', 'for'],
#  'shut': ['for', 'the', 'don', 'the'],
#  'weekend': ['shit'],
#  'gluten': ['free'],
#  'free': ['which', 'range', 'unscheduled', 'just', 'activity'],
#  'means': ['eat', 'gotta', 'the', 'when', 'you'],
#  'bread': ['that', 'that', 'that'],
#  'tastes': ['like', 'when'],
#  'range': ['chewbacca'],
#  'chewbacca': ['eat'],
#  'lesbian': ['bread'],
#  'thousand': ['percent'],
#  'daily': ['fiber', 'basis', 'basis'],
#  'fiber': ['and'],
#  'spoken': ['word'],
#  'word': ['poetry', 'bossy', 'bossy'],
#  'poetry': ['when'],
#  'queef': ['shitty'],
#  'shitty': ['poem', 'dads', 'mom'],
#  'poem': ['about'],
#  'supporting': ['caitlyn'],
#  'caitlyn': ['jenner'],
#  'jenner': ['whatever'],
#  'funny': ['right', 'man'],
#  'sometimes': ['all'],
#  'hippy': ['dippy'],
#  'dippy': ['shit'],
#  'doing': ['impression', 'anything', 'jack', 'now'],
#  'impression': ['asian'],
#  'scrolls': ['the'],
#  'wall': ['and', 'that'],
#  'neither': ['know'],
#  'seems': ['very', 'providing'],
#  'well': ['with', 'don', 'asian'],
#  'buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'pier': ['imports'],
#  'imports': ['that'],
#  'providing': ['some'],
#  'some': ['good', 'because', 'risk', 'useful', 'lame', 'point', 'this'],
#  'good': ['feng', 'could', 'the', 'night'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house': ['him', 'skin', 'hey'],
#  'four': ['years', 'days'],
#  'years': ['and', 'and', 'packed', 'old', 'old'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose': ['because', 'god'],
#  'pressuring': ['him'],
#  'wacky': ['women'],
#  'intuition': ['that'],
#  'proposals': ['really'],
#  'work': ['woman',
#   'anymore',
#   'anymore',
#   'anymore',
#   'when',
#   'office',
#   'because',
#   'time',
#   'anymore',
#   'anymore',
#   'can',
#   'die'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'passively': ['and'],
#  'doesn': ['get', 'see', 'have', 'have', 'believe'],
#  'message': ['extremely'],
#  'extremely': ['aggressively', 'itchy'],
#  'aggressively': ['you'],
#  'threaten': ['leave'],
#  'without': ['ever'],
#  'actually': ['leaving'],
#  'leaving': ['because'],
#  'late': ['back'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'stick': ['with', 'your'],
#  'focus': ['trapping'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['and'],
#  'gets': ['fed', 'very'],
#  'fed': ['and'],
#  'fine': ['will', 'because', 'stage'],
#  'marry': ['and', 'him'],
#  'always': ['like', 'very', 'feel', 'catch', 'means', 'tell', 'wanted'],
#  'proposed': ['came'],
#  'nowhere': ['and', 'and'],
#  'look': ['got',
#   'that',
#   'that',
#   'the',
#   'their',
#   'like',
#   'the',
#   'you',
#   'forward',
#   'like',
#   'like'],
#  'exact': ['ring'],
#  'ring': ['wanted'],
#  'wanted': ['how', 'now', 'him', 'scared'],
#  'maybe': ['saw', 'you', 'because'],
#  'pinterest': ['page', 'page'],
#  'page': ['something', 'probably'],
#  'sent': ['best'],
#  'best': ['friend', 'you'],
#  'friend': ['that'],
#  'send': ['him'],
#  'pinterested': ['men'],
#  'engaged': ['saturday'],
#  'saturday': ['bought'],
#  'bought': ['wedding', 'bike', 'our'],
#  'dress': ['the'],
#  'following': ['tuesday'],
#  'tuesday': ['because'],
#  'tried': ['was', 'freak', 'freak'],
#  'ready': ['was'],
#  'ripe': ['was'],
#  'rotten': ['need', 'was'],
#  'banana': ['bread'],
#  'surprised': ['how'],
#  'completely': ['different', 'gonna'],
#  'recognize': ['personality', 'your'],
#  'personality': ['all'],
#  'soft': ['and', 'serve'],
#  'nurturing': ['and'],
#  'domestic': ['been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day', 'night'],
#  'become': ['dependent', 'the', 'housewife', 'this', 'you', 'some'],
#  'dependent': ['cause'],
#  'graduated': ['from', 'from'],
#  'feed': ['him'],
#  'goodness': ['heart'],
#  'heart': ['investment'],
#  'investment': ['financial'],
#  'financial': ['future'],
#  'reading': ['that'],
#  'book': ['sheryl', 'that', 'called'],
#  'sheryl': ['sandberg', 'sandberg'],
#  'sandberg': ['she', 'that'],
#  'facebook': ['and'],
#  'wrote': ['that', 'lean'],
#  'riled': ['about'],
#  'careers': ['talking'],
#  'talking': ['about', 'about', 'about'],
#  'should': ['challenge', 'not', 'never'],
#  'challenge': ['ourselves'],
#  'ourselves': ['sit'],
#  'sit': ['the', 'down'],
#  'table': ['and', 'and', 'was'],
#  'rise': ['the', 'fame'],
#  'top': ['and'],
#  'lean': ['well', 'wanna', 'has'],
#  'lie': ['down', 'the'],
#  'want': ['lie',
#   'they',
#   'you',
#   'their',
#   'sure',
#   'husband',
#   'noah',
#   'wanna',
#   'for',
#   'able',
#   'your'],
#  'feminism': ['the'],
#  'job': ['used', 'had', 'fresh', 'most'],
#  'used': ['job', 'very', 'leverage'],
#  'smart': ['thing'],
#  'continue': ['playing'],
#  'dumb': ['for', 'women'],
#  'century': ['and', 'more'],
#  'guess': ['better', 'who'],
#  'stay': ['home', 'home', 'that'],
#  'snacks': ['and'],
#  'watch': ['ellen', 'property', 'when', 'the'],
#  'ellen': ['cause'],
#  'stupid': ['have', 'ass'],
#  'real': ['responsibility', 'boss', 'miracle'],
#  'bitch': ['shut', 'genius', 'had'],
#  'ruined': ['for'],
#  'expected': ['work'],
#  'hear': ['the', 'workers', 'that'],
#  'phrase': ['double', 'black'],
#  'income': ['household', 'bracket'],
#  'household': ['wanna'],
#  'upset': ['with'],
#  'comments': ['and'],
#  'options': ['now', 'when'],
#  'unscheduled': ['unsupervised'],
#  'unsupervised': ['and'],
#  'most': ['importantly', 'strong', 'bed', 'likely', 'the', 'the', 'women'],
#  'importantly': ['sponsored'],
#  'sponsored': ['you'],
#  'shittier': ['food'],
#  'food': ['tastes'],
#  'earn': ['lot'],
#  'walk': ['around'],
#  'judgmental': ['about'],
#  'housewives': ['that', 'they', 'get', 'they', 'are', 'they'],
#  'street': ['and'],
#  'housewife': ['not', 'just', 'she', 'financially'],
#  'walking': ['around', 'like'],
#  'massages': ['her'],
#  'lululemon': ['pants'],
#  'pants': ['like', 'any'],
#  'genius': ['she'],
#  'retired': ['write'],
#  'write': ['for'],
#  'fresh': ['off', 'off'],
#  'boat': ['abc', 'would'],
#  'abc': ['yeah'],
#  'great': ['show', 'writing', 'dad'],
#  'workers': ['great', 'blow', 'blow', 'and'],
#  'writing': ['staff', 'job'],
#  'terms': ['day'],
#  'jobs': ['probably'],
#  'still': ['gotta', 'here'],
#  'office': ['every', 'every', 'housewives', 'toilet'],
#  'skin': ['seat', 'every'],
#  'seat': ['they'],
#  'use': ['that', 'that', 'the'],
#  'toilet': ['paper',
#   'paper',
#   'paper',
#   'paper',
#   'paper',
#   'and',
#   'lose',
#   'the',
#   'and'],
#  'paper': ['cover', 'that', 'that', 'that', 'two'],
#  'cover': ['they'],
#  'times': ['day'],
#  'sad': ['ass'],
#  'meal': ['they'],
#  'ply': ['toilet'],
#  'purposely': ['make'],
#  'difficult': ['pull'],
#  'pull': ['out'],
#  'try': ['ration', 'make', 'you', 'tell', 'think'],
#  'ration': ['with'],
#  'communist': ['toilet'],
#  'effective': ['basically'],
#  'dehydrates': ['your'],
#  'wiping': ['your', 'work', 'and'],
#  'desert': ['literally'],
#  'literally': ['spat', 'trying'],
#  'spat': ['toilet'],
#  'days': ['ago', 'out', 'took', 'finally'],
#  'ago': ['try'],
#  'macgyver': ['baby'],
#  'baby': ['wipe',
#   'they',
#   'that',
#   'little',
#   'and',
#   'head',
#   'comes',
#   'hasn',
#   'can',
#   'can',
#   'from'],
#  'wipe': ['moisten'],
#  'moisten': ['and'],
#  'backfired': ['cause'],
#  'fingers': ['broke',
#   'god',
#   'afterwards',
#   'when',
#   'housewives',
#   'when',
#   'when',
#   'nature',
#   'are',
#   'like'],
#  'broke': ['through', 'with'],
#  'digitally': ['stimulated'],
#  'stimulated': ['more'],
#  'doo': ['doo',
#   'come',
#   'doo',
#   'all',
#   'doo',
#   'comes',
#   'doo',
#   'comes',
#   'doo',
#   'the'],
#  'finish': ['wiping', 'wiping', 'could', 'when'],
#  'rushed': ['cause'],
#  'paranoid': ['that'],
#  'worker': ['gonna'],
#  'shoes': ['underneath', 'whatevs'],
#  'underneath': ['the', 'the'],
#  'stall': ['and'],
#  'courtney': ['listening'],
#  'listening': ['she'],
#  'waiting': ['she', 'for'],
#  'timing': ['and'],
#  'hurry': ['hurry', 'hurry', 'and', 'the'],
#  'feels': ['caked'],
#  'caked': ['doo'],
#  'long': ['and', 'they'],
#  'dare': ['scratch', 'you'],
#  'scratch': ['yourself', 'the', 'myself', 'and', 'sniff', 'what', 'yourself'],
#  'yourself': ['your', 'tonight', 'all'],
#  'underwear': ['the', 'and'],
#  'end': ['the'],
#  'looks': ['like'],
#  'goonies': ['housewives'],
#  'muffle': ['their'],
#  'worry': ['about', 'cause'],
#  'velocity': ['with'],
#  'squeeze': ['the'],
#  'cheeks': ['together'],
#  'sure': ['that', 'that', 'all'],
#  'slow': ['and'],
#  'steady': ['pace'],
#  'pace': ['that'],
#  'unpredictable': ['noise'],
#  'noise': ['suddenly'],
#  'suddenly': ['escapes'],
#  'escapes': ['and'],
#  'brings': ['you'],
#  'deep': ['deep', 'shame'],
#  'shame': ['housewives', 'your', 'they'],
#  'blow': ['ass', 'ass', 'ass', 'bubble'],
#  'echo': ['and'],
#  'reverberate': ['the'],
#  'ends': ['their'],
#  'hallways': ['while'],
#  'while': ['watching', 'gets', 'sat', 'get'],
#  'watching': ['much', 'porn', 'porn'],
#  'netflix': ['their'],
#  'ipad': ['they'],
#  'boring': ['repressed', 'and'],
#  'repressed': ['shits'],
#  'shits': ['they'],
#  'listen': ['podcasts'],
#  'podcasts': ['planet'],
#  'planet': ['money'],
#  'distracting': ['for'],
#  'lose': ['respect'],
#  'respect': ['for', 'you', 'and'],
#  'holds': ['any', 'the'],
#  'sort': ['credence'],
#  'credence': ['heard'],
#  'heard': ['one', 'you'],
#  'nerve': ['come'],
#  'bananas': ['saw'],
#  'green': ['ballet'],
#  'ballet': ['flats'],
#  'flats': ['know'],
#  'father': ['law'],
#  'law': ['had'],
#  'recently': ['and', 'bought'],
#  'talk': ['you', 'cause', 'gonna', 'about'],
#  'provide': ['your'],
#  'children': ['with', 'keep', 'there'],
#  'same': ['kind', 'when'],
#  'privileged': ['childhood'],
#  'childhood': ['that'],
#  'telling': ['this'],
#  'conversation': ['you'],
#  'son': ['that', 'for'],
#  'understand': ['that'],
#  'earning': ['potential'],
#  'else': ['would', 'want', 'has', 'you'],
#  'choose': ['fuck'],
#  'rest': ['life', 'your'],
#  'chose': ['marry'],
#  'promise': ['early'],
#  'early': ['retirement', 'and'],
#  'retirement': ['and'],
#  'said': ['what', 'when', 'but'],
#  'meant': ['was'],
#  'dieting': ['anymore'],
#  'since': ['got', 'that'],
#  'eating': ['fried', 'mango'],
#  'fried': ['chicken'],
#  'chicken': ['skin'],
#  'fulfilling': ['destiny'],
#  'destiny': ['which', 'old'],
#  'circle': ['with'],
#  'eyelashes': ['like'],
#  'mrs': ['pacman'],
#  'pacman': ['just'],
#  'redecorate': ['gave'],
#  'myself': ['when', 'every', 'underneath'],
#  'disgusting': ['pervert'],
#  'pervert': ['pervert', 'gross'],
#  'gross': ['filthy'],
#  'filthy': ['animal'],
#  'animal': ['and'],
#  'started': ['watching'],
#  'porn': ['very', 'young'],
#  'young': ['age', 'age'],
#  'age': ['and', 'that'],
#  'happens': ['when', 'for', 'because'],
#  'sicker': ['and', 'and', 'the', 'and', 'and', 'but'],
#  'images': ['you'],
#  'crave': ['get'],
#  'internet': ['will', 'would'],
#  'idiot': ['dude'],
#  'realize': ['that'],
#  'went': ['craigslist', 'harvard'],
#  'craigslist': ['and', 'that'],
#  'posted': ['tiny'],
#  'tiny': ['asian'],
#  'female': ['seeking', 'comic', 'comics', 'stand'],
#  'seeking': ['anal'],
#  'anal': ['the', 'and', 'eventually', 'just'],
#  'crash': ['and'],
#  'male': ['heads', 'comics'],
#  'heads': ['the'],
#  'universe': ['would'],
#  'simultaneously': ['explode'],
#  'explode': ['they', 'lot'],
#  'freaked': ['out'],
#  'scared': ['the',
#   'the',
#   'the',
#   'doo',
#   'that',
#   'they',
#   'that',
#   'like',
#   'about',
#   'childbirth'],
#  'pain': ['you', 'women', 'what', 'away'],
#  'ain': ['scared'],
#  'wax': ['their'],
#  'eyebrows': ['they'],
#  'sorts': ['crazy'],
#  'crazy': ['shit', 'double', 'pregnant'],
#  'dick': ['you'],
#  'evil': ['all'],
#  'secrets': ['and'],
#  'lies': ['sephora'],
#  'sephora': ['can'],
#  'puts': ['the'],
#  'thinking': ['about'],
#  'call': ['mom'],
#  'dad': ['dave', 'and'],
#  'dave': ['grandma', 'chappelle', 'chappelle'],
#  'eventually': ['you'],
#  'change': ['you', 'that', 'and', 'the'],
#  'cheat': ['each'],
#  'keep': ['interesting', 'walking', 'company', 'him', 'him'],
#  'interesting': ['you'],
#  'holes': ['maybe'],
#  'sexually': ['active'],
#  'active': ['and'],
#  'result': ['little'],
#  'little': ['bit',
#   'little',
#   'push',
#   'atari',
#   'cunt',
#   'piece',
#   'bit',
#   'considered',
#   'considered'],
#  'bit': ['stretched', 'science', 'zombie'],
#  'stretched': ['out'],
#  'finally': ['did', 'had', 'leave'],
#  'felt': ['like', 'bad'],
#  'chance': ['life'],
#  'magical': ['big', 'clit'],
#  'fantasy': ['mine'],
#  'mine': ['before'],
#  'possible': ['discover', 'that'],
#  'discover': ['their'],
#  'prostate': ['yeah'],
#  'conqueror': ['just'],
#  'haven': ['done'],
#  'treat': ['yourself'],
#  'tonight': ['you'],
#  'only': ['live', 'which', 'and', 'fuck', 'four'],
#  'live': ['once', 'you', 'until', 'forever'],
#  'once': ['yolo', 'just', 'they', 'they'],
#  'yolo': ['just'],
#  'sneak': ['your'],
#  'give': ['your', 'him', 'fuck', 'husband'],
#  'push': ['push', 'the', 'pop', 'you', 'you', 'and'],
#  'tush': ['tush', 'just'],
#  'atari': ['you'],
#  'resistance': ['from'],
#  'squirmy': ['wormy'],
#  'wormy': ['because'],
#  'thumb': ['there'],
#  'succeed': ['and'],
#  'gay': ['and'],
#  'fear': ['that', 'metamorphosizes'],
#  'turns': ['you', 'into', 'out'],
#  'especially': ['when', 'the', 'when'],
#  'metamorphosizes': ['into'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Everything was like you know what doula you guys can also disappear and she doesn.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %% [markdown]
# ### Assignment Solution-
# 1. Generate sentence for other comedians also.

# %%
gabriel_text = data.transcript.loc['gabriel']
gabriel_text[:200]
# Out:
# 'can you please state your name martin moreno but you might know martinnnnn been touring with gabriel iglesias for plus years martinnnnn and yeah been screaming name for plus years hurry martinnnnn dud'

# %%
gabriel_dict = markov_chain(gabriel_text)
gabriel_dict
# Out:
# {'can': ['you',
#   'people',
#   'all',
#   'say',
#   'make',
#   'cheer',
#   'see',
#   'even',
#   'let',
#   'tell',
#   'the',
#   'nail',
#   'only',
#   'fire',
#   'make',
#   'leave',
#   'leave',
#   'with',
#   'with',
#   'fix',
#   'canceled',
#   'canceled',
#   'come',
#   'you',
#   'move',
#   'make',
#   'give',
#   'see',
#   'decide',
#   'almost',
#   'smell',
#   'have',
#   'have',
#   'inside',
#   'you',
#   'enjoy',
#   'enjoy',
#   'have',
#   'you',
#   'look',
#   'you',
#   'ready',
#   'you',
#   'back',
#   'make',
#   'ready',
#   'talk',
#   'you',
#   'you',
#   'longer',
#   'longer',
#   'take',
#   'get',
#   'only',
#   'mess',
#   'miss',
#   'help',
#   'change',
#   'get',
#   'get',
#   'hang',
#   'have',
#   'lock',
#   'see',
#   'barely',
#   'cause',
#   'smell',
#   'tell',
#   'follow',
#   'por',
#   'can',
#   'hope',
#   'too'],
#  'you': ['please',
#   'might',
#   'selling',
#   'make',
#   'stick',
#   'want',
#   'much',
#   'very',
#   'much',
#   'know',
#   'just',
#   'finally',
#   'mexican',
#   'white',
#   'guys',
#   'know',
#   'can',
#   'know',
#   'yeah',
#   'home',
#   'gonna',
#   'tell',
#   'what',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'don',
#   'know',
#   'doesn',
#   'you',
#   'are',
#   'all',
#   'smoking',
#   'mask',
#   'smell',
#   'will',
#   'know',
#   'skank',
#   'here',
#   'what',
#   'because',
#   'know',
#   'wanted',
#   'couldn',
#   'had',
#   'know',
#   'couldn',
#   'have',
#   'know',
#   'this',
#   'know',
#   'give',
#   'and',
#   'park',
#   'have',
#   'are',
#   'are',
#   'get',
#   'get',
#   'have',
#   'just',
#   'have',
#   'know',
#   'remember',
#   'are',
#   'can',
#   'want',
#   'know',
#   'want',
#   'want',
#   'know',
#   'know',
#   'yes',
#   'not',
#   'that',
#   'that',
#   'guys',
#   'think',
#   'too',
#   'turn',
#   'okay',
#   'like',
#   'and',
#   'have',
#   'got',
#   'guys',
#   'understand',
#   'guys',
#   'anyway',
#   'guys',
#   'the',
#   'were',
#   'going',
#   'get',
#   'can',
#   'still',
#   'know',
#   'are',
#   'found',
#   'know',
#   'heard',
#   'know',
#   'know',
#   'only',
#   'want',
#   'cannot',
#   'twitter',
#   'will',
#   'stupid',
#   'know',
#   'made',
#   'fox',
#   'stupid',
#   'and',
#   'not',
#   'better',
#   'much',
#   'being',
#   'have',
#   'have',
#   'said',
#   'feel',
#   'mean',
#   'know',
#   'have',
#   'that',
#   'would',
#   'know',
#   'know',
#   'would',
#   'think',
#   'can',
#   'choose',
#   'didn',
#   'needed',
#   'get',
#   'get',
#   'get',
#   'wow',
#   'start',
#   'can',
#   'stupid',
#   'know',
#   'mean',
#   'know',
#   'about',
#   'vegan',
#   'can',
#   'and',
#   'can',
#   'are',
#   'are',
#   'weren',
#   'going',
#   'know',
#   'already',
#   'feel',
#   'here',
#   'heard',
#   'stupid',
#   'horrible',
#   'thought',
#   'really',
#   'and',
#   'know',
#   'horrible',
#   'mean',
#   'you',
#   'know',
#   'doing',
#   'mean',
#   'guys',
#   'mess',
#   'aside',
#   'the',
#   'consider',
#   'still',
#   'gotta',
#   'are',
#   'make',
#   'know',
#   'keep',
#   'how',
#   'and',
#   'guys',
#   'were',
#   'sent',
#   'fed',
#   'tagging',
#   'could',
#   'know',
#   'all',
#   'don',
#   'gonna',
#   'are',
#   'cannot',
#   'can',
#   'realize',
#   'professional',
#   'professional',
#   'need',
#   'heard',
#   'like',
#   'then',
#   'will',
#   'say',
#   'have',
#   'are',
#   'reporting',
#   'the',
#   'warn',
#   'talking',
#   'did',
#   'know',
#   'know',
#   'fucking',
#   'know',
#   'know',
#   'know',
#   'remember',
#   'host',
#   'know',
#   'please',
#   'apologized',
#   'apologize',
#   'can',
#   'have',
#   'don',
#   'cannot',
#   'but',
#   'and',
#   'but',
#   'want',
#   'can',
#   'very',
#   'honor',
#   'thank',
#   'honor',
#   'know',
#   'know',
#   'guys',
#   'know',
#   'like',
#   'know',
#   'got',
#   'like',
#   'live',
#   'walk',
#   'try',
#   'try',
#   'their',
#   'staring',
#   'itself',
#   'about',
#   'come',
#   'are',
#   'back',
#   'can',
#   'where',
#   'where',
#   'and',
#   'don',
#   'know',
#   'more',
#   'and',
#   'guys',
#   'wish',
#   'have',
#   'but',
#   'see',
#   'guys',
#   'all',
#   'fart',
#   'feel',
#   'are',
#   'let',
#   'can',
#   'could',
#   'could',
#   'must',
#   'plan',
#   'start',
#   'know',
#   'and',
#   'saying',
#   'were',
#   'mean',
#   'not',
#   'guys',
#   'have',
#   'you',
#   'can',
#   'you',
#   'can',
#   'kind',
#   'know',
#   'gonna',
#   'then',
#   'placed',
#   'know',
#   'something',
#   'see',
#   'vocal',
#   'can',
#   'said',
#   'have',
#   'get',
#   'understand',
#   'just',
#   'guys',
#   'say',
#   'hear',
#   'say',
#   'for',
#   'know',
#   'always',
#   'know',
#   'have',
#   'have',
#   'gotta',
#   'got',
#   'don',
#   'going',
#   'home',
#   'know',
#   'take',
#   'the',
#   'think',
#   'know',
#   'know',
#   'famous',
#   'take',
#   'taking',
#   'say',
#   'spend',
#   'not',
#   'please',
#   'have',
#   'can',
#   'cannot',
#   'are',
#   'guys',
#   'eat',
#   'idiot',
#   'son',
#   'know',
#   'explain',
#   'baby',
#   'here',
#   'doing',
#   'for',
#   'dropped',
#   'know',
#   'guys',
#   'out',
#   'know',
#   'thinking',
#   'have',
#   'can',
#   'know',
#   'the',
#   'know',
#   'dad',
#   'okay',
#   'please',
#   'talking',
#   'talking',
#   'please',
#   'felt',
#   'ever',
#   'told',
#   'and',
#   'did',
#   'that',
#   'don',
#   'know',
#   'they',
#   'died',
#   'died',
#   'guys',
#   'got',
#   'though',
#   'supposed',
#   'like',
#   'have',
#   'supposed',
#   'young',
#   'little',
#   'resilient',
#   'realize',
#   'devastated',
#   'your',
#   'that',
#   'know',
#   'know',
#   'guys',
#   'know',
#   'sad',
#   'weak',
#   'vulnerable',
#   'need',
#   'can',
#   'keep',
#   'what',
#   'know',
#   'feel',
#   'and',
#   'guys',
#   'know',
#   'experience',
#   'seen',
#   'just',
#   'say',
#   'pushed',
#   'sittin',
#   'the',
#   'what',
#   'are',
#   'should',
#   'was',
#   'sittin',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'ever',
#   'start',
#   'find',
#   'know',
#   'are',
#   'have',
#   'are',
#   'right',
#   'notice',
#   'start',
#   'start',
#   'start',
#   'chance',
#   'back',
#   'just',
#   'happy',
#   'the',
#   'can',
#   'could',
#   'are',
#   'start',
#   'remember',
#   'would',
#   'thought',
#   'look',
#   'get',
#   'got',
#   'and',
#   'say',
#   'were',
#   'know',
#   'got',
#   'know',
#   'are',
#   'are',
#   'and',
#   'are',
#   'never',
#   'don',
#   'being',
#   'over',
#   'your',
#   'trying',
#   'know',
#   'and',
#   'pinned',
#   'she',
#   'with',
#   'will',
#   'welcome',
#   'hear',
#   'don',
#   'don',
#   'can',
#   'can',
#   'didn',
#   'gonna',
#   'before',
#   'don',
#   'this',
#   'too',
#   'the',
#   'how',
#   'the',
#   'already',
#   'know',
#   'and',
#   'know',
#   'can',
#   'bro',
#   'think',
#   'doing',
#   'accept',
#   'and',
#   'drink',
#   'drink',
#   'take',
#   'take',
#   'know',
#   'know',
#   'get',
#   'everything',
#   'and',
#   'what',
#   'could',
#   'know',
#   'take',
#   'take',
#   'take',
#   'know',
#   'know',
#   'god',
#   'guys',
#   'were',
#   'were',
#   'asshole',
#   'been',
#   'right',
#   'are',
#   'say',
#   'have',
#   'know',
#   'know',
#   'guys',
#   'going',
#   'get',
#   'been',
#   'been',
#   'know',
#   'was',
#   'can',
#   'you',
#   'are',
#   'for',
#   'for',
#   'thank',
#   'thank',
#   'this',
#   'guys',
#   'right',
#   'guys',
#   'can',
#   'follow',
#   'don',
#   'guys',
#   'know',
#   'know'],
#  'please': ['state',
#   'don',
#   'keep',
#   'explain',
#   'have',
#   'for',
#   'sit',
#   'stop',
#   'don',
#   'for',
#   'chase'],
#  'state': ['your', 'that', 'with', 'where'],
#  'your': ['name',
#   'jimmy',
#   'secret',
#   'loved',
#   'family',
#   'mama',
#   'papa',
#   'ass',
#   'front',
#   'family',
#   'guilt',
#   'bodies',
#   'arm',
#   'car',
#   'face',
#   'body',
#   'covid',
#   'bubble',
#   'little',
#   'extortion',
#   'voice',
#   'thoughts',
#   'real',
#   'credibility',
#   'rate',
#   'fee',
#   'salad',
#   'eating',
#   'cause',
#   'face',
#   'fighting',
#   'strategy',
#   'plan',
#   'plan',
#   'social',
#   'cats',
#   'cats',
#   'son',
#   'face',
#   'dogs',
#   'little',
#   'beverage',
#   'little',
#   'puppies',
#   'son',
#   'son',
#   'specials',
#   'bucket',
#   'mom',
#   'candy',
#   'candy',
#   'thing',
#   'heart',
#   'first',
#   'first',
#   'forties',
#   'forties',
#   'achy',
#   'heart',
#   'life',
#   'life',
#   'mind',
#   'car',
#   'car',
#   'hair',
#   'day',
#   'bus',
#   'life',
#   'phone',
#   'dms',
#   'phone',
#   'social',
#   'woman',
#   'business',
#   'relationship',
#   'ass',
#   'ass',
#   'stories',
#   'writing',
#   'living',
#   'name',
#   'years',
#   'career',
#   'career',
#   'career',
#   'dreams',
#   'dream',
#   'email'],
#  'name': ['martin',
#   'for',
#   'corona',
#   'gabriel',
#   'steven',
#   'speedy',
#   'should',
#   'canelo',
#   'ron',
#   'something',
#   'was',
#   'come',
#   'mail'],
#  'martin': ['moreno',
#   'real',
#   'wasn',
#   'alfred',
#   'not',
#   'dude',
#   'martin',
#   'that',
#   'hosting',
#   'request',
#   'and',
#   'walking',
#   'baby',
#   'hears',
#   'grabs',
#   'martin',
#   'martin',
#   'and',
#   'gone',
#   'comes',
#   'pops',
#   'face',
#   'says',
#   'start',
#   'just',
#   'half',
#   'all',
#   'give',
#   'did'],
#  'moreno': ['but'],
#  'but': ['you',
#   'when',
#   'yeah',
#   'they',
#   'that',
#   'yeah',
#   'was',
#   'for',
#   'yeah',
#   'they',
#   'look',
#   'hope',
#   'none',
#   'they',
#   'you',
#   'more',
#   'disguises',
#   'speedy',
#   'can',
#   'the',
#   'guess',
#   'hands',
#   'whatever',
#   'and',
#   'think',
#   'with',
#   'they',
#   'not',
#   'causes',
#   'again',
#   'would',
#   'there',
#   'does',
#   'then',
#   'point',
#   'know',
#   'guess',
#   'basically',
#   'thank',
#   'thank',
#   'cat',
#   'then',
#   'yeah',
#   'shit',
#   'she',
#   'you',
#   'remember',
#   'the',
#   'when',
#   'they',
#   'never',
#   'better',
#   'that',
#   'anyway',
#   'because',
#   'not',
#   'you',
#   'the',
#   'notice',
#   'cool',
#   'based',
#   'this',
#   'gonna',
#   'can',
#   'recorded',
#   'wasn'],
#  'might': ['know', 'well', 'you', 'get'],
#  'know': ['martinnnnn',
#   'some',
#   'this',
#   'what',
#   'how',
#   'some',
#   'what',
#   'the',
#   'and',
#   'there',
#   'then',
#   'what',
#   'trying',
#   'for',
#   'was',
#   'look',
#   'where',
#   'where',
#   'fifty',
#   'and',
#   'but',
#   'can',
#   'how',
#   'bus',
#   'was',
#   'lot',
#   'thank',
#   'some',
#   'bring',
#   'with',
#   'whether',
#   'this',
#   'about',
#   'been',
#   'but',
#   'going',
#   'and',
#   'some',
#   'back',
#   'have',
#   'have',
#   'what',
#   'better',
#   'what',
#   'what',
#   'what',
#   'some',
#   'how',
#   'that',
#   'can',
#   'they',
#   'what',
#   'right',
#   'that',
#   'big',
#   'some',
#   'only',
#   'where',
#   'cause',
#   'that',
#   'going',
#   'what',
#   'like',
#   'hey',
#   'feels',
#   'after',
#   'you',
#   'what',
#   'who',
#   'and',
#   'you',
#   'what',
#   'what',
#   'well',
#   'you',
#   'you',
#   'for',
#   'don',
#   'the',
#   'that',
#   'reminded',
#   'they',
#   'didn',
#   'they',
#   'gotta',
#   'sorry',
#   'nothin',
#   'gabriel',
#   'technically',
#   'since',
#   'each',
#   'what',
#   'what',
#   'what',
#   'one',
#   'better',
#   'what',
#   'there',
#   'what',
#   'and',
#   'you',
#   'what',
#   'what',
#   'parties',
#   'some',
#   'how',
#   'what',
#   'that',
#   'that',
#   'what',
#   'never',
#   'what',
#   'how',
#   'been',
#   'make',
#   'what',
#   'what',
#   'just',
#   'showering',
#   'unless',
#   'who',
#   'you',
#   'too',
#   'they',
#   'that',
#   'yet',
#   'martin',
#   'they',
#   'that',
#   'didn',
#   'drinking',
#   'her',
#   'what',
#   'gone',
#   'that',
#   'the',
#   'she',
#   'very',
#   'are',
#   'hear',
#   'the',
#   'some',
#   'that',
#   'that',
#   'you',
#   'love',
#   'chased',
#   'why',
#   'that',
#   'that',
#   'what',
#   'what'],
#  'martinnnnn': ['been', 'and', 'dude'],
#  'been': ['touring',
#   'screaming',
#   'incredible',
#   'the',
#   'out',
#   'telling',
#   'smoking',
#   'over',
#   'prouder',
#   'mexican',
#   'like',
#   'signed',
#   'cut',
#   'known',
#   'brought',
#   'all',
#   'looking',
#   'distracted',
#   'happy',
#   'like',
#   'referred',
#   'hour',
#   'sharing',
#   'signed',
#   'seven',
#   'seven',
#   'over',
#   'asked',
#   'single',
#   'hunted',
#   'around',
#   'there',
#   'the',
#   'one',
#   'many',
#   'very',
#   'the',
#   'the',
#   'bad',
#   'bad'],
#  'touring': ['with'],
#  'with': ['gabriel',
#   'bomb',
#   'foreman',
#   'your',
#   'your',
#   'your',
#   'you',
#   'your',
#   'one',
#   'netflix',
#   'time',
#   'roaches',
#   'the',
#   'that',
#   'covid',
#   'you',
#   'covid',
#   'models',
#   'kevin',
#   'ten',
#   'that',
#   'lebron',
#   'mon',
#   'tweet',
#   'the',
#   'all',
#   'you',
#   'she',
#   'the',
#   'nasty',
#   'cancel',
#   'the',
#   'the',
#   'the',
#   'everyone',
#   'who',
#   'canelo',
#   'well',
#   'problem',
#   'tradition',
#   'face',
#   'jesus',
#   'didn',
#   'the',
#   'the',
#   'dogs',
#   'you',
#   'this',
#   'dog',
#   'dogs',
#   'candy',
#   'and',
#   'what',
#   'the',
#   'his',
#   'for',
#   'snot',
#   'mocos',
#   'mocos',
#   'babas',
#   'drool',
#   'baby',
#   'the',
#   'you',
#   'friend',
#   'the',
#   'her',
#   'you',
#   'the',
#   'that',
#   'that',
#   'salt',
#   'sharing',
#   'such',
#   'you',
#   'your',
#   'dream',
#   'topics',
#   'her'],
#  'gabriel': ['iglesias',
#   'iglesias',
#   'iglesias',
#   'thank',
#   'were',
#   'iglesias',
#   'iglesias',
#   'mic',
#   'not',
#   'fluffy',
#   'you',
#   'don',
#   'iglesias',
#   'iglesias',
#   'you',
#   'iglesias',
#   'iglesias',
#   'all',
#   'what',
#   'iglesias',
#   'iglesias',
#   'iglesias'],
#  'iglesias': ['for',
#   'california',
#   'and',
#   'how',
#   'for',
#   'yes',
#   'thank',
#   'and',
#   'this',
#   'all',
#   'pulled',
#   'ladies'],
#  'for': ['plus',
#   'plus',
#   'your',
#   'them',
#   'the',
#   'this',
#   'was',
#   'some',
#   'two',
#   'using',
#   'covid',
#   'some',
#   'the',
#   'minutes',
#   'okay',
#   'reason',
#   'recording',
#   'the',
#   'the',
#   'days',
#   'roaches',
#   'example',
#   'you',
#   'the',
#   'days',
#   'some',
#   'covid',
#   'obvious',
#   'ten',
#   'problems',
#   'lending',
#   'you',
#   'all',
#   'speedy',
#   'living',
#   'you',
#   'space',
#   'living',
#   'half',
#   'the',
#   'less',
#   'little',
#   'one',
#   'that',
#   'using',
#   'the',
#   'one',
#   'whole',
#   'free',
#   'certain',
#   'previous',
#   'the',
#   'previous',
#   'previous',
#   'that',
#   'the',
#   'the',
#   'you',
#   'espn',
#   'mgm',
#   'thought',
#   'this',
#   'the',
#   'kevin',
#   'the',
#   'the',
#   'something',
#   'fact',
#   'one',
#   'one',
#   'food',
#   'themselves',
#   'their',
#   'your',
#   'clapping',
#   'some',
#   'work',
#   'give',
#   'him',
#   'halloween',
#   'the',
#   'take',
#   'least',
#   'you',
#   'some',
#   'this',
#   'this',
#   'him',
#   'fact',
#   'while',
#   'almost',
#   'the',
#   'over',
#   'long',
#   'long',
#   'the',
#   'legal',
#   'the',
#   'the',
#   'shot',
#   'him',
#   'soothing',
#   'cough',
#   'help',
#   'security',
#   'the',
#   'number',
#   'someone',
#   'because',
#   'gabriel',
#   'you',
#   'god',
#   'the',
#   'years',
#   'the',
#   'martin',
#   'the',
#   'please',
#   'sacrifice'],
#  'plus': ['years',
#   'years',
#   'and',
#   'wanted',
#   'was',
#   'medical',
#   'myself',
#   'was',
#   'years'],
#  'years': ['martinnnnn',
#   'hurry',
#   'and',
#   'worth',
#   'old',
#   'and',
#   'ago',
#   'ago',
#   'ago',
#   'apart',
#   'now',
#   'old',
#   'old',
#   'okay',
#   'ago',
#   'you',
#   'ago',
#   'every',
#   'doing',
#   'you',
#   'thank',
#   'ago',
#   'like'],
#  'and': ['yeah',
#   'now',
#   'whatever',
#   'pimps',
#   'already',
#   'you',
#   'backyard',
#   'quincea',
#   'weddings',
#   'now',
#   'glad',
#   'then',
#   'all',
#   'watched',
#   'gentlemen',
#   'apologize',
#   'your',
#   'covid',
#   'covid',
#   'them',
#   'you',
#   'two',
#   'little',
#   'african',
#   'her',
#   'here',
#   'finally',
#   'tres',
#   'not',
#   'was',
#   'then',
#   'then',
#   'they',
#   'got',
#   'the',
#   'glance',
#   'notice',
#   'that',
#   'all',
#   'get',
#   'locked',
#   'could',
#   'like',
#   'she',
#   'have',
#   'she',
#   'doing',
#   'during',
#   'the',
#   'had',
#   'remember',
#   'just',
#   'then',
#   'the',
#   'get',
#   'they',
#   'said',
#   'basically',
#   'course',
#   'you',
#   'like',
#   'then',
#   'when',
#   'let',
#   'not',
#   'don',
#   'lived',
#   'california',
#   'movement',
#   'the',
#   'that',
#   'she',
#   'she',
#   'little',
#   'she',
#   'she',
#   'she',
#   'kept',
#   'said',
#   'she',
#   'she',
#   'just',
#   'for',
#   'told',
#   'said',
#   'the',
#   'clearly',
#   'they',
#   'career',
#   'clearly',
#   'lot',
#   'with',
#   'like',
#   'that',
#   'wasn',
#   'two',
#   'speedy',
#   'fast',
#   'twitter',
#   'friend',
#   'did',
#   'wrote',
#   'the',
#   'posted',
#   'used',
#   'before',
#   'know',
#   'kind',
#   'you',
#   'producer',
#   'they',
#   'the',
#   'then',
#   'assumed',
#   'that',
#   'then',
#   'you',
#   'soon',
#   'soon',
#   'all',
#   'producer',
#   'said',
#   'don',
#   'was',
#   'said',
#   'would',
#   'more',
#   'just',
#   'like',
#   'the',
#   'like',
#   'have',
#   'don',
#   'the',
#   'your',
#   'the',
#   'they',
#   'they',
#   'friends',
#   'little',
#   'she',
#   'then',
#   'then',
#   'you',
#   'don',
#   'they',
#   'then',
#   'ally',
#   'trying',
#   'into',
#   'impossible',
#   'then',
#   'reads',
#   'simple',
#   'know',
#   'you',
#   'the',
#   'then',
#   'then',
#   'show',
#   'tested',
#   'you',
#   'understand',
#   'know',
#   'apologize',
#   'get',
#   'you',
#   'ron',
#   'told',
#   'couple',
#   'ron',
#   'figure',
#   'then',
#   'here',
#   'was',
#   'you',
#   'spanish',
#   'you',
#   'ask',
#   'like',
#   'like',
#   'boom',
#   'your',
#   'then',
#   'out',
#   'know',
#   'the',
#   'get',
#   'always',
#   'they',
#   'nervous',
#   'the',
#   'any',
#   'they',
#   'kevin',
#   'apologized',
#   'the',
#   'need',
#   'kevin',
#   'they',
#   'kevin',
#   'walked',
#   'can',
#   'everyone',
#   'the',
#   'based',
#   'turned',
#   'think',
#   'then',
#   'gentlemen',
#   'welcome',
#   'gentlemen',
#   'they',
#   'then',
#   'show',
#   'why',
#   'now',
#   'someone',
#   'run',
#   'then',
#   'down',
#   'makes',
#   'pees',
#   'then',
#   'apologize',
#   'christmas',
#   'the',
#   'the',
#   'losing',
#   'blow',
#   'know',
#   'the',
#   'the',
#   'get',
#   'just',
#   'know',
#   'street',
#   'for',
#   'then',
#   'was',
#   'responded',
#   'then',
#   'just',
#   'allowing',
#   'tell',
#   'then',
#   'order',
#   'talk',
#   'look',
#   'know',
#   'there',
#   'some',
#   'instead',
#   'like',
#   'she',
#   'these',
#   'leave',
#   'she',
#   'now',
#   'hear',
#   'she',
#   'then',
#   'chihuahuas',
#   'put',
#   'your',
#   'make',
#   'someone',
#   'said',
#   'that',
#   'goes',
#   'for',
#   'son',
#   'stay',
#   'give',
#   'take',
#   'start',
#   'not',
#   'hasn',
#   'frankie',
#   'frankie',
#   'lead',
#   'got',
#   'said',
#   'froze',
#   'the',
#   'was',
#   'tell',
#   'course',
#   'she',
#   'immediately',
#   'they',
#   'don',
#   'for',
#   'girl',
#   'down',
#   'frankie',
#   'then',
#   'give',
#   'look',
#   'said',
#   'lead',
#   'get',
#   'starts',
#   'that',
#   'just',
#   'just',
#   'overheard',
#   'like',
#   'you',
#   'one',
#   'caught',
#   'when',
#   'said',
#   'knew',
#   'don',
#   'that',
#   'hope',
#   'frustrations',
#   'not',
#   'need',
#   'did',
#   'yeah',
#   'got',
#   'like',
#   'then',
#   'that',
#   'there',
#   'had',
#   'some',
#   'people',
#   'you',
#   'was',
#   'you',
#   'tell',
#   'crying',
#   'they',
#   'then',
#   'say',
#   'don',
#   'started',
#   'lands',
#   'knew',
#   'did',
#   'the',
#   'play',
#   'play',
#   'play',
#   'came',
#   'your',
#   'artists',
#   'not',
#   'all',
#   'now',
#   'doesn',
#   'locked',
#   'now',
#   'the',
#   'over',
#   'like',
#   'know',
#   'there',
#   'cons',
#   'then',
#   'then',
#   'shit',
#   'decides',
#   'now',
#   'there',
#   'then',
#   'you',
#   'would',
#   'then',
#   'they',
#   'the',
#   'you',
#   'here',
#   'she',
#   'she',
#   'seconds',
#   'netflix',
#   'all',
#   'everyone',
#   'love',
#   'then',
#   'any',
#   'stairs',
#   'introduces',
#   'then',
#   'then',
#   'shoot',
#   'have',
#   'turn',
#   'martin',
#   'like',
#   'like',
#   'here',
#   'the',
#   'guess',
#   'wanted',
#   'she',
#   'doubled',
#   'she',
#   'the',
#   'like',
#   'then',
#   'then',
#   'sprinkles',
#   'then',
#   'rubs',
#   'the',
#   'they',
#   'like',
#   'here',
#   'walks',
#   'holding',
#   'goes',
#   'gave',
#   'said',
#   'everyone',
#   'then',
#   'then',
#   'then',
#   'walked',
#   'this',
#   'gets',
#   'holds',
#   'goes',
#   'grab',
#   'full',
#   'said',
#   'freaked',
#   'said',
#   'everyone',
#   'then',
#   'then',
#   'then',
#   'licked',
#   'questioning',
#   'have',
#   'sitting',
#   'tell',
#   'thank',
#   'they',
#   'that',
#   'they',
#   'see',
#   'looking',
#   'like',
#   'security',
#   'security',
#   'start',
#   'held',
#   'said',
#   'they',
#   'reaching',
#   'was',
#   'then',
#   'all',
#   'she',
#   'nothing',
#   'she',
#   'her',
#   'her',
#   'all',
#   'this',
#   'now',
#   'goes',
#   'see',
#   'his',
#   'crawled',
#   'when',
#   'whoo',
#   'martin',
#   'gentlemen',
#   'then',
#   'little',
#   'his',
#   'from',
#   'threw',
#   'honestly',
#   'snoop',
#   'last',
#   'tonight',
#   'write',
#   'then',
#   'share',
#   'sometimes',
#   'they',
#   'whatever',
#   'then',
#   'the',
#   'bunch',
#   'then',
#   'break',
#   'then',
#   'watch',
#   'that',
#   'met',
#   'ivan',
#   'went',
#   'when',
#   'never',
#   'know',
#   'you',
#   'something',
#   'know',
#   'hopefully',
#   'would',
#   'always',
#   'she',
#   'that',
#   'that',
#   'always',
#   'die',
#   'then',
#   'just',
#   'gentlemen',
#   'gabriel',
#   'gentlemen',
#   'tell',
#   'saw',
#   'said',
#   'donald',
#   'why',
#   'the',
#   'much'],
#  'yeah': ['been',
#   'after',
#   'yeah',
#   'lost',
#   'were',
#   'just',
#   'bye',
#   'the',
#   'honest',
#   'could',
#   'let',
#   'top',
#   'okay',
#   'fucking',
#   'and',
#   'see',
#   'like',
#   'and',
#   'but',
#   'every',
#   'that',
#   'pay',
#   'was',
#   'people',
#   'know',
#   'her',
#   'real',
#   'you',
#   'half',
#   'let',
#   'that',
#   'pretty',
#   'you',
#   'see',
#   'dog',
#   'she',
#   'these',
#   'yes',
#   'they',
#   'they',
#   'son',
#   'park',
#   'what',
#   'what',
#   'not',
#   'hat'],
#  'screaming': ['name'],
#  'hurry': ['martinnnnn'],
#  'dude': ['that', 'don', 'heard', 'clock', 'about', 'what'],
#  'that': ['better',
#   'win',
#   'longer',
#   'untouchable',
#   'sunshine',
#   'you',
#   'for',
#   'the',
#   'was',
#   'had',
#   'they',
#   'you',
#   'all',
#   'the',
#   'they',
#   'the',
#   'what',
#   'your',
#   'what',
#   'the',
#   'way',
#   'fine',
#   'vaccine',
#   'you',
#   'racist',
#   'accurate',
#   'really',
#   'where',
#   'weird',
#   'cuca',
#   'roach',
#   'freakin',
#   'moment',
#   'she',
#   'visibly',
#   'roach',
#   'shit',
#   'were',
#   'tested',
#   'someone',
#   'what',
#   'shit',
#   'like',
#   'like',
#   'they',
#   'they',
#   'they',
#   'not',
#   'called',
#   'said',
#   'when',
#   'would',
#   'personally',
#   'perhaps',
#   'you',
#   'they',
#   'did',
#   'could',
#   'can',
#   'right',
#   'loud',
#   'was',
#   'just',
#   'rabbit',
#   'shit',
#   'they',
#   'would',
#   'they',
#   'how',
#   'some',
#   'not',
#   'why',
#   'why',
#   'right',
#   'not',
#   'basically',
#   'see',
#   'place',
#   'blew',
#   'tweet',
#   'chick',
#   'are',
#   'got',
#   'was',
#   'all',
#   'some',
#   'based',
#   'done',
#   'just',
#   'when',
#   'there',
#   'you',
#   'you',
#   'said',
#   'right',
#   'what',
#   'god',
#   'did',
#   'team',
#   'have',
#   'going',
#   'face',
#   'where',
#   'someone',
#   'knows',
#   'was',
#   'almost',
#   'was',
#   'kevin',
#   'ten',
#   'were',
#   'you',
#   'kevin',
#   'what',
#   'why',
#   'was',
#   'sold',
#   'why',
#   'would',
#   'but',
#   'why',
#   'sorry',
#   'amazing',
#   'you',
#   'free',
#   'sounds',
#   'way',
#   'lot',
#   'shit',
#   'guilty',
#   'one',
#   'holding',
#   'was',
#   'doing',
#   'about',
#   'sorry',
#   'shit',
#   'shit',
#   'anyone',
#   'walked',
#   'louder',
#   'bitch',
#   'did',
#   'joke',
#   'nothing',
#   'awesome',
#   'never',
#   'not',
#   'you',
#   'great',
#   'neighborhood',
#   'neighborhood',
#   'gives',
#   'hour',
#   'golden',
#   'went',
#   'cheated',
#   'good',
#   'other',
#   'person',
#   'joke',
#   'year',
#   'you',
#   'the',
#   'story',
#   'been',
#   'and',
#   'never',
#   'never',
#   'called',
#   'spoke',
#   'they',
#   'important',
#   'think',
#   'lot',
#   'longer',
#   'going',
#   'said',
#   'still',
#   'did',
#   'when',
#   'when',
#   'when',
#   'when',
#   'when',
#   'longer',
#   'tour',
#   'found',
#   'right',
#   'right',
#   'was',
#   'will',
#   'makes',
#   'car',
#   'you',
#   'horse',
#   'friend',
#   'you',
#   'being',
#   'happiness',
#   'brand',
#   'guys',
#   'song',
#   'one',
#   'why',
#   'you',
#   'are',
#   'like',
#   'what',
#   'brought',
#   'why',
#   'right',
#   'all',
#   'the',
#   'opens',
#   'lead',
#   'held',
#   'and',
#   'ger',
#   'commits',
#   'just',
#   'small',
#   'have',
#   'drinker',
#   'can',
#   'person',
#   'compliment',
#   'drink',
#   'person',
#   'like',
#   'way',
#   'this',
#   'lot',
#   'night',
#   'girl',
#   'little',
#   'football',
#   'that',
#   'people',
#   'story',
#   'with',
#   'always',
#   'did',
#   'talked',
#   'people',
#   'for',
#   'ask',
#   'and',
#   'saying',
#   'how',
#   'could',
#   'there',
#   'when',
#   'person',
#   'mom',
#   'she',
#   'was',
#   'you',
#   'someone',
#   'made',
#   'right',
#   'somewhere',
#   'few',
#   'reflects',
#   'didn'],
#  'better': ['than',
#   'ask',
#   'understand',
#   'their',
#   'and',
#   'life',
#   'know',
#   'get',
#   'maybe'],
#  'than': ['most',
#   'two',
#   'later',
#   'and',
#   'year',
#   'woke',
#   'later',
#   'one',
#   'dogs',
#   'cough',
#   'dogs',
#   'that'],
#  'most': ['marriages', 'risk', 'risk', 'normal', 'optimistic', 'attractive'],
#  'marriages': ['that'],
#  'win': ['has'],
#  'has': ['been',
#   'ever',
#   'given',
#   'been',
#   'work',
#   'ever',
#   'ever',
#   'teeth',
#   'been',
#   'single',
#   'thinking',
#   'least',
#   'been',
#   'you',
#   'gone',
#   'two',
#   'formed',
#   'the',
#   'been',
#   'been',
#   'been'],
#  'incredible': ['journey', 'wanted', 'moments'],
#  'journey': ['gone'],
#  'gone': ['from',
#   'way',
#   'diet',
#   'home',
#   'over',
#   'somewhere',
#   'can',
#   'this',
#   'and',
#   'and'],
#  'from': ['garages',
#   'dodger',
#   'texas',
#   'the',
#   'yeah',
#   'manager',
#   'west',
#   'living',
#   'full',
#   'your',
#   'the',
#   'anyone',
#   'the',
#   'friends',
#   'counter',
#   'the',
#   'shut',
#   'this',
#   'him',
#   'and',
#   'the',
#   'day',
#   'the',
#   'tight',
#   'the'],
#  'garages': ['clubs', 'and'],
#  'clubs': ['living', 'the'],
#  'living': ['rooms', 'room', 'and', 'given', 'different', 'room'],
#  'rooms': ['theaters'],
#  'theaters': ['arenas', 'was'],
#  'arenas': ['around'],
#  'around': ['the', 'till', 'was', 'someone', 'good', 'long'],
#  'the': ['world',
#   'biggest',
#   'end',
#   'city',
#   'city',
#   'city',
#   'city',
#   'wild',
#   'track',
#   'city',
#   'state',
#   'game',
#   'big',
#   'biggest',
#   'only',
#   'fact',
#   'goddamn',
#   'secret',
#   'secret',
#   'news',
#   'same',
#   'one',
#   'one',
#   'house',
#   'face',
#   'black',
#   'underlying',
#   'mask',
#   'mask',
#   'mask',
#   'onlyfans',
#   'vaccine',
#   'underlying',
#   'dice',
#   'vaccine',
#   'beginning',
#   'vaccine',
#   'face',
#   'vaccine',
#   'window',
#   'next',
#   'whole',
#   'car',
#   'radio',
#   'going',
#   'sidewalk',
#   'protestors',
#   'car',
#   'lady',
#   'car',
#   'vaccine',
#   'vaccine',
#   'gauntlet',
#   'pandemic',
#   'other',
#   'story',
#   'original',
#   'new',
#   'series',
#   'last',
#   'option',
#   'mexican',
#   'real',
#   'big',
#   'door',
#   'light',
#   'wall',
#   'wall',
#   'light',
#   'roach',
#   'room',
#   'accommodations',
#   'room',
#   'wall',
#   'wall',
#   'wall',
#   'wall',
#   'stool',
#   'second',
#   'day',
#   'only',
#   'roach',
#   'way',
#   'city',
#   'vaccine',
#   'opportunity',
#   'footage',
#   'message',
#   'deadline',
#   'see',
#   'first',
#   'only',
#   'story',
#   'same',
#   'comedy',
#   'groupon',
#   'window',
#   'pandemic',
#   'movie',
#   'movie',
#   'new',
#   'slowest',
#   'fastest',
#   'only',
#   'new',
#   'pooh',
#   'pooh',
#   'house',
#   'zoom',
#   'director',
#   'voice',
#   'only',
#   'little',
#   'simpsons',
#   'character',
#   'fact',
#   'power',
#   'sound',
#   'end',
#   'day',
#   'movie',
#   'question',
#   'voice',
#   'part',
#   'you',
#   'phone',
#   'voice',
#   'guy',
#   'call',
#   'only',
#   'call',
#   'sound',
#   'flow',
#   'tempo',
#   'timing',
#   'fastest',
#   'director',
#   'mexican',
#   'opportunity',
#   'entire',
#   'martian',
#   'other',
#   'whole',
#   'middle',
#   'fact',
#   'conversation',
#   'producer',
#   'producer',
#   'one',
#   'finance',
#   'money',
#   'director',
#   'man',
#   'street',
#   'way',
#   'one',
#   'fact',
#   'only',
#   'vegans',
#   'rage',
#   'caption',
#   'majority',
#   'room',
#   'groan',
#   'other',
#   'ones',
#   'problem',
#   'time',
#   'past',
#   'lgbtq',
#   'letters',
#   'letters',
#   'limited',
#   'limited',
#   'thing',
#   'riot',
#   'conversation',
#   'lgbtq',
#   'same',
#   'staff',
#   'wrong',
#   'cause',
#   'only',
#   'years',
#   'call',
#   'time',
#   'best',
#   'world',
#   'whitest',
#   'name',
#   'troops',
#   'national',
#   'show',
#   'troops',
#   'show',
#   'host',
#   'reporter',
#   'announcer',
#   'mgm',
#   'reporter',
#   'fight',
#   'microphone',
#   'camera',
#   'ground',
#   'fight',
#   'mgm',
#   'sport',
#   'fight',
#   'how',
#   'floor',
#   'studio',
#   'hell',
#   'joke',
#   'boxing',
#   'best',
#   'world',
#   'troops',
#   'national',
#   'confrontation',
#   'reason',
#   'fights',
#   'jumbotron',
#   'fear',
#   'fact',
#   'best',
#   'reason',
#   'oscars',
#   'year',
#   'year',
#   'story',
#   'oscars',
#   'background',
#   'way',
#   'academy',
#   'tweets',
#   'academy',
#   'same',
#   'oscars',
#   'job',
#   'same',
#   'academy',
#   'same',
#   'job',
#   'other',
#   'academy',
#   'academy',
#   'oscars',
#   'vibe',
#   'night',
#   'material',
#   'oscars',
#   'opening',
#   'oscars',
#   'vibe',
#   'night',
#   'voice',
#   'academy',
#   'oscars',
#   'swing',
#   'fact',
#   'world',
#   'reaction',
#   'same',
#   'greatest',
#   'couch',
#   'dog',
#   'super',
#   'world',
#   'same',
#   'lights',
#   'goodyear',
#   'sky',
#   'energy',
#   'back',
#   'people',
#   'people',
#   'most',
#   'car',
#   'car',
#   'underlying',
#   'mistake',
#   'guy',
#   'stand',
#   'rule',
#   'stand',
#   'front',
#   'car',
#   'guy',
#   'difference',
#   'option',
#   'doors',
#   'floor',
#   'fact',
#   'whole',
#   'grid',
#   'complete',
#   'car',
#   'front',
#   'lady',
#   'back',
#   'guy',
#   'menu',
#   'girl',
#   'car',
#   'little',
#   'menu',
#   'cup',
#   'house',
#   'night',
#   'fact',
#   'house',
#   'past',
#   'first',
#   'thing',
#   'fact',
#   'three',
#   'two',
#   'opportunity',
#   'car',
#   'costco',
#   'car',
#   'street',
#   'doors',
#   'people',
#   'fluffy',
#   'fluffy',
#   'door',
#   'way',
#   'street',
#   'way',
#   'time',
#   'car',
#   'bucket',
#   'house',
#   'hell',
#   'score',
#   'whole',
#   'hell',
#   'point',
#   'point',
#   'two',
#   'car',
#   'way',
#   'candy',
#   'candy',
#   'cart',
#   'cart',
#   'cart',
#   'third',
#   'first',
#   'car',
#   'three',
#   'empire',
#   'bucket',
#   'table',
#   'same',
#   'same',
#   'same',
#   'ball',
#   'two',
#   'car',
#   'way',
#   'candy',
#   'candy',
#   'cart',
#   'shelf',
#   'cart',
#   'shopping',
#   'first',
#   'story',
#   'hero',
#   'past',
#   'best',
#   'audience',
#   'future',
#   'issues',
#   'fact',
#   'woman',
#   'end',
#   'day',
#   'breakup',
#   'first',
#   'gas',
#   'car',
#   'car',
#   'gas',
#   'shows',
#   'lowest',
#   'lowest',
#   'void',
#   'face',
#   'car',
#   'same',
#   'stereo',
#   'country',
#   'station',
#   'mistakes',
#   'people',
#   'artist',
#   'song',
#   'songs',
#   'sudden',
#   'radio',
#   'ground',
#   'door',
#   'same',
#   'guys',
#   'game',
#   'game',
#   'world',
#   'most',
#   'world',
#   'way',
#   'relationship',
#   'minute',
#   'street',
#   'whole',
#   'difference',
#   'most',
#   'world',
#   'water',
#   'sharks',
#   'scariest',
#   'world',
#   'back',
#   'same',
#   'people',
#   'good',
#   'show',
#   'show',
#   'show',
#   'city',
#   'pike',
#   'story',
#   'ending',
#   'ending',
#   'people',
#   'end',
#   'story',
#   'improv',
#   'improv',
#   'country',
#   'difference',
#   'country',
#   'dressing',
#   'comics',
#   'stage',
#   'stage',
#   'second',
#   'stairs',
#   'microphone',
#   'show',
#   'corner',
#   'tray',
#   'tray',
#   'audience',
#   'front',
#   'front',
#   'girl',
#   'whole',
#   'hell',
#   'tray',
#   'lime',
#   'front',
#   'whole',
#   'hell',
#   'stage',
#   'shot',
#   'glass',
#   'front',
#   'glass',
#   'drink',
#   'guy',
#   'wrong',
#   'glass',
#   'glass',
#   'entire',
#   'glass',
#   'other',
#   'stage',
#   'problem',
#   'bar',
#   'shot',
#   'bartender',
#   'shot',
#   'bar',
#   'fact',
#   'first',
#   'sake',
#   'back',
#   'room',
#   'sudden',
#   'stage',
#   'crowd',
#   'other',
#   'other',
#   'stage',
#   'door',
#   'stairs',
#   'microphone',
#   'ground',
#   'end',
#   'chest',
#   'stairs',
#   'stairs',
#   'top',
#   'top',
#   'stairs',
#   'crowd',
#   'other',
#   'problem',
#   'credibility',
#   'show',
#   'story',
#   'question',
#   'years',
#   'stories',
#   'end',
#   'stories',
#   'stories',
#   'button',
#   'number',
#   'oscars',
#   'fact',
#   'timeline',
#   'snapchat',
#   'shows',
#   'camcorder',
#   'tripod',
#   'hotel',
#   'little',
#   'back',
#   'and',
#   'thing',
#   'bag',
#   'hotel',
#   'camera',
#   'hotel',
#   'tape',
#   'tape',
#   'person',
#   'footage',
#   'tape',
#   'last',
#   'same',
#   'greatest',
#   'last',
#   'fact',
#   'greatest',
#   'problem',
#   'question',
#   'greatest',
#   'greatest',
#   'greatest',
#   'wrong',
#   'officer',
#   'officer',
#   'window',
#   'greatest',
#   'memory',
#   'man',
#   'freaking',
#   'midterm',
#   'hilarious',
#   'last',
#   'extravagant',
#   'loft'],
#  'world': ['and',
#   'okay',
#   'every',
#   'okay',
#   'was',
#   'will',
#   'series',
#   'than',
#   'nothing',
#   'who',
#   'cause'],
#  'now': ['stadium',
#   'let',
#   'like',
#   'you',
#   'have',
#   'disrespect',
#   'pep',
#   'you',
#   'remember',
#   'will',
#   'don',
#   'some',
#   'forgive',
#   'gonna',
#   'let',
#   'for',
#   'but',
#   'that',
#   'and',
#   'worried',
#   'now',
#   'the',
#   'you',
#   'have',
#   'thank',
#   'big',
#   'worried',
#   'you',
#   'very',
#   'years',
#   'doing',
#   'here',
#   'different',
#   'october',
#   'have',
#   'you',
#   'you',
#   'and',
#   'are',
#   'know',
#   'and',
#   'you',
#   'you',
#   'blood',
#   'over',
#   'fluffy',
#   'happened',
#   'the',
#   'and',
#   'reaching',
#   'standing',
#   'the',
#   'the',
#   'are',
#   'your',
#   'this'],
#  'stadium': ['they', 'gabriel', 'netflix', 'elbow', 'perform'],
#  'they': ['say',
#   'want',
#   'want',
#   'closed',
#   'told',
#   'told',
#   'used',
#   'told',
#   'told',
#   'harpoon',
#   'make',
#   'didn',
#   'kept',
#   'gave',
#   'got',
#   'were',
#   'were',
#   'scatter',
#   'respond',
#   'weren',
#   'were',
#   'were',
#   'said',
#   'were',
#   'were',
#   'did',
#   'hit',
#   'hired',
#   'trying',
#   'came',
#   'came',
#   'see',
#   'being',
#   'like',
#   'just',
#   'knew',
#   'actually',
#   'still',
#   'told',
#   'said',
#   'were',
#   'closed',
#   'talking',
#   'only',
#   'don',
#   'don',
#   'just',
#   'expect',
#   'not',
#   'said',
#   'reached',
#   'gave',
#   'probably',
#   'put',
#   'through',
#   'said',
#   'been',
#   'said',
#   'reached',
#   'were',
#   'said',
#   'passed',
#   'passed',
#   'kept',
#   'kept',
#   'turn',
#   'get',
#   'know',
#   'get',
#   'been',
#   'just',
#   'got',
#   'working',
#   'tell',
#   'tell',
#   'said',
#   'did',
#   'did',
#   'put',
#   'chihuahuas',
#   'supposed',
#   'least',
#   'adorable',
#   'cute',
#   'adorable',
#   'too',
#   'they',
#   'free',
#   'let',
#   'welcome',
#   'said',
#   'opened',
#   'were',
#   'got',
#   'gonna',
#   'understand',
#   'gonna',
#   'blending',
#   'blending',
#   'were',
#   'can',
#   'stare',
#   'point',
#   'come',
#   'flashing',
#   'making',
#   'walked',
#   'can',
#   'know',
#   'like',
#   'like',
#   'watching',
#   'don',
#   'want',
#   'say',
#   'laugh',
#   'going'],
#  'say': ['comedy',
#   'without',
#   'about',
#   'way',
#   'was',
#   'thank',
#   'again',
#   'thank',
#   'piso',
#   'this',
#   'that',
#   'you',
#   'that',
#   'someone',
#   'one',
#   'what',
#   'got',
#   'that',
#   'you',
#   'about',
#   'about',
#   'anything',
#   'she',
#   'that',
#   'another',
#   'this',
#   'this',
#   'say',
#   'thank',
#   'have',
#   'how',
#   'why',
#   'get'],
#  'comedy': ['subjective',
#   'totem',
#   'specials',
#   'specials',
#   'friend',
#   'show',
#   'show',
#   'and',
#   'material',
#   'club',
#   'club',
#   'club',
#   'they',
#   'what',
#   'roots'],
#  'subjective': ['but', 'what'],
#  'when': ['you',
#   'got',
#   'you',
#   'protesters',
#   'got',
#   'tell',
#   'tell',
#   'you',
#   'got',
#   'said',
#   'you',
#   'people',
#   'everything',
#   'perform',
#   'see',
#   'you',
#   'they',
#   'you',
#   'come',
#   'gets',
#   'would',
#   'engaging',
#   'you',
#   'they',
#   'they',
#   'talked',
#   'she',
#   'first',
#   'get',
#   'said',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'everything',
#   'hit',
#   'became',
#   'was',
#   'couldn',
#   'you',
#   'you',
#   'you',
#   'brand',
#   'was',
#   'that',
#   'walked',
#   'send',
#   'got',
#   'comes',
#   'came',
#   'this',
#   'you'],
#  'selling': ['out', 'the'],
#  'out': ['stadiums',
#   'here',
#   'martin',
#   'anthony',
#   'people',
#   'was',
#   'you',
#   'location',
#   'this',
#   'there',
#   'team',
#   'someone',
#   'claiming',
#   'theaters',
#   'that',
#   'say',
#   'gabriel',
#   'she',
#   'that',
#   'line',
#   'one',
#   'online',
#   'and',
#   'say',
#   'one',
#   'that',
#   'sooner',
#   'and',
#   'you',
#   'here',
#   'same',
#   'what',
#   'because',
#   'tell',
#   'the',
#   'that',
#   'couple',
#   'bunch',
#   'bunch',
#   'stadium',
#   'the',
#   'looking',
#   'their',
#   'gyro',
#   'trying',
#   'like',
#   'and',
#   'candy',
#   'the',
#   'one',
#   'one',
#   'your',
#   'his',
#   'the',
#   'matt',
#   'trick',
#   'candy',
#   'you',
#   'face',
#   'loud',
#   'that',
#   'and',
#   'loud',
#   'the',
#   'the',
#   'because',
#   'take',
#   'the',
#   'jokes',
#   'onstage',
#   'there',
#   'krispy',
#   'there'],
#  'stadiums': ['that'],
#  'longer': ['subjective', 'with', 'home', 'option', 'back', 'watching'],
#  'what': ['can',
#   'else',
#   'was',
#   'saying',
#   'your',
#   'this',
#   'you',
#   'you',
#   'gonna',
#   'they',
#   'everyone',
#   'been',
#   'you',
#   'with',
#   'happened',
#   'the',
#   'you',
#   'say',
#   'that',
#   'house',
#   'god',
#   'career',
#   'his',
#   'are',
#   'you',
#   'are',
#   'made',
#   'gonna',
#   'doc',
#   'are',
#   'you',
#   'are',
#   'your',
#   'your',
#   'they',
#   'happens',
#   'you',
#   'tell',
#   'you',
#   'you',
#   'was',
#   'trying',
#   'lawyer',
#   'will',
#   'your',
#   'your',
#   'waiting',
#   'the',
#   'happened',
#   'are',
#   'heard',
#   'does',
#   'saying',
#   'was',
#   'come',
#   'the',
#   'did',
#   'the',
#   'make',
#   'other',
#   'cat',
#   'about',
#   'son',
#   'they',
#   'are',
#   'you',
#   'yee',
#   'are',
#   'are',
#   'are',
#   'kind',
#   'you',
#   'mom',
#   'you',
#   'that',
#   'about',
#   'saying',
#   'say',
#   'the',
#   'thought',
#   'was',
#   'are',
#   'saying',
#   'tell',
#   'maybe',
#   'baby',
#   'about',
#   'thinking',
#   'have',
#   'important',
#   'are',
#   'are',
#   'tells',
#   'did',
#   'knew',
#   'mean',
#   'called',
#   'mean',
#   'going',
#   'deserve',
#   'piece',
#   'now',
#   'are',
#   'like',
#   'like',
#   'concerning',
#   'the',
#   'the',
#   'that',
#   'you',
#   'are',
#   'going',
#   'going',
#   'feel',
#   'gonna',
#   'and',
#   'your',
#   'camcorder',
#   'need',
#   'has',
#   'has',
#   'has',
#   'don',
#   'kevin',
#   'can'],
#  'people': ['expect',
#   'ask',
#   'over',
#   'who',
#   'there',
#   'much',
#   'from',
#   'that',
#   'find',
#   'but',
#   'see',
#   'the',
#   'are',
#   'need',
#   'that',
#   'together',
#   'watching',
#   'vegans',
#   'trying',
#   'need',
#   'over',
#   'behind',
#   'behind',
#   'needed',
#   'freaked',
#   'were',
#   'hurt',
#   'the',
#   'when',
#   'have',
#   'los',
#   'that',
#   'holding',
#   'are',
#   'have',
#   'have',
#   'asking',
#   'would',
#   'laugh',
#   'are',
#   'ask',
#   'and',
#   'would'],
#  'expect': ['one', 'you', 'apologize'],
#  'one': ['the',
#   'that',
#   'listen',
#   'those',
#   'them',
#   'was',
#   'that',
#   'else',
#   'gabriel',
#   'responsible',
#   'telling',
#   'week',
#   'dogs',
#   'wants',
#   'place',
#   'they',
#   'was',
#   'night',
#   'year',
#   'tweet',
#   'the',
#   'the',
#   'wanted',
#   'had',
#   'night',
#   'your',
#   'minute',
#   'hour',
#   'those',
#   'night',
#   'night',
#   'thing',
#   'there',
#   'was',
#   'when',
#   'take',
#   'guy',
#   'door',
#   'another',
#   'more',
#   'year',
#   'but',
#   'time',
#   'day',
#   'those',
#   'those',
#   'and',
#   'song',
#   'some',
#   'the',
#   'the',
#   'hour',
#   'orlando',
#   'orlando',
#   'there',
#   'more',
#   'the',
#   'question',
#   'number',
#   'longest',
#   'ivan',
#   'night',
#   'those',
#   'specific',
#   'thing',
#   'thing',
#   'night'],
#  'biggest': ['shows', 'thing', 'complaint'],
#  'shows': ['los',
#   'your',
#   'before',
#   'days',
#   'with',
#   'before',
#   'martin',
#   'what',
#   'using',
#   'and'],
#  'los': ['angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'angeles',
#   'long'],
#  'angeles': ['has',
#   'did',
#   'you',
#   'and',
#   'and',
#   'awesome',
#   'love',
#   'every',
#   'east'],
#  'ever': ['seen',
#   'done',
#   'given',
#   'gone',
#   'see',
#   'gonna',
#   'had',
#   'every',
#   'shows',
#   'tried',
#   'been',
#   'wanted'],
#  'seen': ['and', 'canelo', 'her', 'her', 'enough'],
#  'whatever': ['you',
#   'that',
#   'free',
#   'know',
#   'you',
#   'you',
#   'you',
#   'you',
#   'doesn',
#   'your'],
#  'make': ['sure',
#   'some',
#   'appointment',
#   'biscuits',
#   'you',
#   'deposit',
#   'movie',
#   'sure',
#   'this',
#   'contributions',
#   'money',
#   'apologize',
#   'good',
#   'our',
#   'things',
#   'better',
#   'eye',
#   'bad',
#   'sure',
#   'this',
#   'fun',
#   'him',
#   'sure',
#   'stop',
#   'work',
#   'choice',
#   'someone',
#   'such',
#   'excuses',
#   'any'],
#  'sure': ['you',
#   'what',
#   'some',
#   'was',
#   'what',
#   'got',
#   'they',
#   'safe',
#   'she',
#   'could'],
#  'stick': ['around'],
#  'till': ['the', 'you'],
#  'end': ['you', 'the', 'the', 'while', 'the', 'boxers', 'mortal', 'last'],
#  'want': ['see',
#   'cry',
#   'cry',
#   'that',
#   'stay',
#   'stay',
#   'you',
#   'get',
#   'them',
#   'them',
#   'donate',
#   'let',
#   'feel',
#   'part',
#   'leave',
#   'leave',
#   'one',
#   'door',
#   'that',
#   'tell',
#   'knew',
#   'any',
#   'make',
#   'feel',
#   'don',
#   'them',
#   'you',
#   'hear',
#   'around',
#   'toast',
#   'rude',
#   'make',
#   'help',
#   'leave',
#   'see'],
#  'see': ['how',
#   'him',
#   'can',
#   'the',
#   'what',
#   'that',
#   'look',
#   'too',
#   'still',
#   'this',
#   'the',
#   'how',
#   'who',
#   'joke',
#   'ron',
#   'shit',
#   'there',
#   'one',
#   'what',
#   'dog',
#   'puddle',
#   'this',
#   'all',
#   'that',
#   'any',
#   'dogs',
#   'that',
#   'that',
#   'you',
#   'how',
#   'drink',
#   'what',
#   'what',
#   'something',
#   'something',
#   'but',
#   'something',
#   'martin',
#   'sorry',
#   'and'],
#  'how': ['this',
#   'party',
#   'party',
#   'cook',
#   'could',
#   'could',
#   'big',
#   'know',
#   'you',
#   'did',
#   'are',
#   'going',
#   'cancel',
#   'hard',
#   'the',
#   'could',
#   'the',
#   'you',
#   'discovered',
#   'got',
#   'you',
#   'come',
#   'you',
#   'are',
#   'much',
#   'happy',
#   'devastating',
#   'about',
#   'about',
#   'far',
#   'hard',
#   'long',
#   'dad',
#   'made',
#   'much',
#   'was',
#   'detailed',
#   'something',
#   'does',
#   'does',
#   'sometimes',
#   'you',
#   'happy',
#   'happy',
#   'happy',
#   'there',
#   'happened',
#   'sorry',
#   'possible',
#   'are',
#   'would',
#   'convenient'],
#  'this': ['thing',
#   'awesome',
#   'this',
#   'home',
#   'this',
#   'cause',
#   'what',
#   'what',
#   'next',
#   'point',
#   'only',
#   'very',
#   'all',
#   'whole',
#   'was',
#   'way',
#   'fancy',
#   'big',
#   'beautiful',
#   'big',
#   'big',
#   'unit',
#   'big',
#   'big',
#   'tejano',
#   'roach',
#   'roach',
#   'tonight',
#   'the',
#   'because',
#   'shit',
#   'part',
#   'entertain',
#   'you',
#   'off',
#   'sound',
#   'guy',
#   'gabriel',
#   'was',
#   'was',
#   'call',
#   'happen',
#   'world',
#   'one',
#   'moment',
#   'the',
#   'coming',
#   'and',
#   'knock',
#   'weekend',
#   'weekend',
#   'weekend',
#   'going',
#   'going',
#   'confrontation',
#   'because',
#   'close',
#   'away',
#   'planet',
#   'last',
#   'this',
#   'like',
#   'you',
#   'playlist',
#   'hola',
#   'guy',
#   'over',
#   'here',
#   'freakin',
#   'and',
#   'vinnie',
#   'risa',
#   'vinnie',
#   'risa',
#   'way',
#   'how',
#   'one',
#   'whole',
#   'planet',
#   'cool',
#   'frankie',
#   'how',
#   'way',
#   'what',
#   'neighborhood',
#   'one',
#   'like',
#   'could',
#   'could',
#   'motherfucker',
#   'soon',
#   'way',
#   'the',
#   'year',
#   'was',
#   'conclusion',
#   'been',
#   'one',
#   'out',
#   'happy',
#   'out',
#   'moment',
#   'now',
#   'next',
#   'story',
#   'story',
#   'comedy',
#   'and',
#   'magical',
#   'guy',
#   'gonna',
#   'double',
#   'holds',
#   'drinking',
#   'point',
#   'point',
#   'what',
#   'guy',
#   'man',
#   'netflix',
#   'not',
#   'the',
#   'point',
#   'taking',
#   'show',
#   'cabr',
#   'special',
#   'and',
#   'says'],
#  'thing': ['ends',
#   'ever',
#   'can',
#   'still',
#   'some',
#   'going',
#   'with',
#   'kevin',
#   'know',
#   'you',
#   'guilty',
#   'ten',
#   'his',
#   'they',
#   'thank',
#   'could',
#   'but',
#   'yeah',
#   'now',
#   'got',
#   'comedian',
#   'the',
#   'you',
#   'could',
#   'that',
#   'love',
#   'you',
#   'someone',
#   'where',
#   'and',
#   'because',
#   'whenever',
#   'left'],
#  'ends': ['what', 'meet'],
#  'else': ['left', 'was', 'got', 'would', 'wanted', 'and'],
#  'left': ['say', 'with', 'say', 'turn'],
#  'without': ['further', 'shadow', 'divulging'],
#  'further': ['ado'],
#  'ado': ['live'],
#  'live': ['from', 'for', 'their'],
#  'dodger': ['stadium'],
#  'california': ['love', 'knows', 'knows', 'roaches', 'they', 'technique'],
#  'love': ['california',
#   'the',
#   'you',
#   'share',
#   'this',
#   'him',
#   'love',
#   'okay',
#   'him',
#   'him',
#   'just',
#   'and',
#   'you',
#   'you',
#   'the',
#   'you',
#   'with'],
#  'knows': ['how',
#   'how',
#   'just',
#   'vegas',
#   'who',
#   'love',
#   'that',
#   'when',
#   'when',
#   'when',
#   'tuesday'],
#  'party': ['california', 'the', 'that'],
#  'city': ['the', 'good', 'the', 'compton', 'sex', 'san', 'los'],
#  'good': ['watts',
#   'thing',
#   'feel',
#   'anyway',
#   'for',
#   'citizens',
#   'sounds',
#   'this',
#   'here',
#   'sucks',
#   'for',
#   'least',
#   'chance',
#   'kevin',
#   'host',
#   'evening',
#   'job',
#   'time',
#   'time',
#   'frankie',
#   'frankie',
#   'story',
#   'vibes',
#   'right',
#   'energy',
#   'people',
#   'held',
#   'went',
#   'intentions',
#   'fortune'],
#  'watts': ['the'],
#  'compton': ['keep'],
#  'keep': ['rockin',
#   'rockin',
#   'his',
#   'with',
#   'free',
#   'cool',
#   'movin',
#   'going',
#   'going',
#   'going',
#   'going',
#   'that'],
#  'rockin': ['keep', 'now'],
#  'let': ['welcome',
#   'have',
#   'see',
#   'tell',
#   'turn',
#   'them',
#   'them',
#   'know',
#   'you',
#   'tell',
#   'tell',
#   'you',
#   'this',
#   'the',
#   'tell',
#   'come',
#   'rip',
#   'known',
#   'the',
#   'just',
#   'tell',
#   'play',
#   'body',
#   'nobody'],
#  'welcome': ['everybody', 'the', 'any', 'any', 'cause'],
#  'everybody': ['the', 'knows', 'here', 'out'],
#  'wild': ['wild', 'west'],
#  'west': ['state', 'covina', 'the'],
#  'untouchable': ['like'],
#  'like': ['eliot',
#   'slug',
#   'machete',
#   'the',
#   'you',
#   'the',
#   'ask',
#   'oreos',
#   'selling',
#   'hey',
#   'everyone',
#   'what',
#   'shit',
#   'you',
#   'bitch',
#   'that',
#   'they',
#   'this',
#   'the',
#   'this',
#   'what',
#   'everything',
#   'big',
#   'would',
#   'take',
#   'she',
#   'move',
#   'soy',
#   'yeah',
#   'need',
#   'let',
#   'seriously',
#   'and',
#   'put',
#   'the',
#   'hyundai',
#   'base',
#   'fluffy',
#   'america',
#   'episode',
#   'gabriel',
#   'lend',
#   'said',
#   'gabriel',
#   'speedy',
#   'that',
#   'yeah',
#   'could',
#   'okay',
#   'gabriel',
#   'look',
#   'whoa',
#   'yeah',
#   'that',
#   'that',
#   'what',
#   'well',
#   'metro',
#   'lot',
#   'you',
#   'god',
#   'look',
#   'this',
#   'this',
#   'this',
#   'this',
#   'going',
#   'yes',
#   'well',
#   'gabriel',
#   'the',
#   'dog',
#   'you',
#   'god',
#   'you',
#   'that',
#   'birthday',
#   'fuck',
#   'don',
#   'you',
#   'which',
#   'hello',
#   'spells',
#   'taco',
#   'couldn',
#   'third',
#   'shit',
#   'not',
#   'well',
#   'see',
#   'well',
#   'puppucci',
#   'what',
#   'don',
#   'can',
#   'canelo',
#   'you',
#   'said',
#   'how',
#   'knows',
#   'she',
#   'think',
#   'the',
#   'god',
#   'god',
#   'all',
#   'what',
#   'show',
#   'there',
#   'she',
#   'sign',
#   'think',
#   'tradition',
#   'really',
#   'good',
#   'can',
#   'real',
#   'when',
#   'wow',
#   'god',
#   'menudo',
#   'the',
#   'got',
#   'single',
#   'relationship',
#   'guess',
#   'maybe',
#   'magic',
#   'you',
#   'share',
#   'share',
#   'star',
#   'this',
#   'shoot',
#   'think',
#   'okay',
#   'let',
#   'whoo',
#   'what',
#   'what',
#   'expired',
#   'was',
#   'dude',
#   'the',
#   'ugh',
#   'ugh',
#   'security',
#   'want',
#   'nanando',
#   'armando',
#   'you',
#   'here',
#   'might',
#   'gonna',
#   'the',
#   'little',
#   'ladies',
#   'that',
#   'that',
#   'legit',
#   'you',
#   'hello',
#   'what',
#   'how',
#   'tell',
#   'never',
#   'you',
#   'this',
#   'falling'],
#  'eliot': ['ness'],
#  'ness': ['the'],
#  'track': ['hits'],
#  'hits': ['eardrum'],
#  'eardrum': ['like'],
#  'slug': ['chest'],
#  'chest': ['pack', 'cause', 'goes'],
#  'pack': ['vest'],
#  'vest': ['for'],
#  'jimmy': ['the'],
#  'sex': ['that'],
#  'sunshine': ['state'],
#  'bomb': ['ass'],
#  'ass': ['hemp',
#   'home',
#   'didn',
#   'roach',
#   'roach',
#   'come',
#   'upstairs',
#   'upstairs'],
#  'hemp': ['beat'],
#  'beat': ['the'],
#  'where': ['never',
#   'you',
#   'got',
#   'got',
#   'stand',
#   'you',
#   'people',
#   'got',
#   'going',
#   'gonna',
#   'were',
#   'were',
#   'were',
#   'just',
#   'there',
#   'didn',
#   'were',
#   'you',
#   'never'],
#  'never': ['find',
#   'had',
#   'done',
#   'lived',
#   'been',
#   'auditioned',
#   'apologize',
#   'brought',
#   'done',
#   'spoken',
#   'made',
#   'been',
#   'once',
#   'told',
#   'liked',
#   'been',
#   'wanted',
#   'wanted',
#   'bring',
#   'felt',
#   'ring',
#   'mind',
#   'been',
#   'look',
#   'recovered',
#   'try',
#   'wanted',
#   'forget',
#   'behave'],
#  'find': ['dance',
#   'out',
#   'out',
#   'out',
#   'out',
#   'them',
#   'him',
#   'out',
#   'out',
#   'out',
#   'out',
#   'suitable',
#   'alternative',
#   'way',
#   'yourself'],
#  'dance': ['floor'],
#  'floor': ['empty', 'going', 'and', 'and', 'there'],
#  'empty': ['and'],
#  'pimps': ['mission'],
#  'mission': ['for'],
#  'them': ['greens',
#   'lie',
#   'right',
#   'and',
#   'were',
#   'money',
#   'hurt',
#   'cancel',
#   'yeah',
#   'think',
#   'think',
#   'but',
#   'out',
#   'little',
#   'shout',
#   'ten',
#   'more',
#   'into',
#   'for',
#   'they',
#   'first',
#   'the',
#   'down',
#   'the',
#   'puppuccino',
#   'out',
#   'think',
#   'and'],
#  'greens': ['lean'],
#  'lean': ['mean', 'over'],
#  'mean': ['money',
#   'well',
#   'well',
#   'really',
#   'and',
#   'can',
#   'said',
#   'was',
#   'good'],
#  'money': ['makin',
#   'some',
#   'from',
#   'the',
#   'but',
#   'hears',
#   'yes',
#   'mayweather',
#   'mayweather',
#   'mayweather'],
#  'makin': ['machines'],
#  'machines': ['servin'],
#  'servin': ['fiends'],
#  'fiends': ['been'],
#  'game': ['los', 'like', 'and', 'not'],
#  'did': ['didn',
#   'thank',
#   'the',
#   'manage',
#   'movie',
#   'and',
#   'story',
#   'get',
#   'voices',
#   'find',
#   'about',
#   'sat',
#   'this',
#   'this',
#   'couldn',
#   'that',
#   'interview',
#   'like',
#   'you',
#   'say',
#   'the',
#   'not',
#   'not',
#   'not',
#   'that',
#   'shots',
#   'included',
#   'really',
#   'that',
#   'everything',
#   'really',
#   'get'],
#  'didn': ['did',
#   'know',
#   'know',
#   'have',
#   'know',
#   'you',
#   'think',
#   'think',
#   'know',
#   'know',
#   'like',
#   'mind',
#   'care',
#   'ask',
#   'want',
#   'want',
#   'know',
#   'know',
#   'want',
#   'want',
#   'pay',
#   'even',
#   'want',
#   'waste',
#   'expected'],
#  'thank': ['you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'dogs',
#   'dogs',
#   'you',
#   'god',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you'],
#  'much': ['thank',
#   'thank',
#   'less',
#   'and',
#   'for',
#   'less',
#   'spanish',
#   'ladies',
#   'cannot',
#   'would',
#   'are',
#   'son',
#   'cause',
#   'candy',
#   'the',
#   'candy',
#   'love',
#   'and',
#   'information',
# ...
#   'career',
#   'life'],
#  'manager': ['walks', 'telling', 'call'],
#  'walks': ['the', 'the'],
#  'everything': ['okay',
#   'was',
#   'they',
#   'the',
#   'was',
#   'been',
#   'all',
#   'had',
#   'ever'],
#  'accommodations': ['said'],
#  'closer': ['she'],
#  'visibly': ['bothered'],
#  'bothered': ['this'],
#  'would': ['you',
#   'have',
#   'have',
#   'like',
#   'give',
#   'have',
#   'have',
#   'want',
#   'never',
#   'change',
#   'not',
#   'have',
#   'have',
#   'even',
#   'have',
#   'make',
#   'and',
#   'like',
#   'have',
#   'that',
#   'home',
#   'immediately',
#   'get',
#   'have',
#   'have',
#   'rather',
#   'love',
#   'like',
#   'look',
#   'never',
#   'not',
#   'know',
#   'record',
#   'review',
#   'even',
#   'like',
#   'ask'],
#  'care': ['your', 'offend', 'walk', 'what'],
#  'emasculating': ['because'],
#  'move': ['fool', 'forward', 'god'],
#  'fool': ['she', 'round'],
#  'takes': ['off', 'the', 'are', 'notice', 'salt', 'the', 'the'],
#  'shoe': ['she', 'put', 'gets', 'she', 'she'],
#  'grabs': ['she', 'her', 'bag', 'second', 'third', 'and', 'lime'],
#  'chair': ['and'],
#  'brings': ['back', 'back', 'people', 'onstage'],
#  'soy': ['bam'],
#  'bam': ['nailed', 'and'],
#  'nailed': ['that'],
#  'threw': ['down', 'underwear'],
#  'moving': ['and', 'forward', 'forward', 'forward'],
#  'angered': ['our'],
#  'defensive': ['fool'],
#  'round': ['two', 'two'],
#  'stool': ['and'],
#  'nail': ['this', 'the'],
#  'second': ['time', 'bag', 'floor', 'one'],
#  'flying': ['was'],
#  'harry': ['potter'],
#  'potter': ['roach'],
#  'aras': ['man'],
#  'film': ['special', 'really', 'all'],
#  'tested': ['positive', 'they'],
#  'positive': ['for', 'you'],
#  'nobody': ['and', 'else', 'wants', 'wants', 'wants', 'tell'],
#  'dealing': ['with', 'with'],
#  'sincere': ['apology'],
#  'apology': ['the'],
#  'supposed': ['tape',
#   'host',
#   'host',
#   'inside',
#   'have',
#   'have',
#   'when',
#   'effective'],
#  'tape': ['special', 'and', 'him', 'know', 'have'],
#  'clearly': ['for', 'this', 'there', 'had', 'and'],
#  'obvious': ['reasons'],
#  'reasons': ['couldn', 'must'],
#  'hope': ['you', 'you', 'spanish', 'you', 'knows', 'somewhere'],
#  'understand': ['why',
#   'little',
#   'that',
#   'them',
#   'that',
#   'that',
#   'spanish',
#   'hold',
#   'how',
#   'one',
#   'why'],
#  'why': ['had',
#   'telling',
#   'don',
#   'talk',
#   'ugh',
#   'was',
#   'didn',
#   'confident',
#   'say',
#   'they',
#   'they',
#   'they',
#   'when',
#   'not',
#   'mom',
#   'wouldn',
#   'there',
#   'moving',
#   'that',
#   'stopped',
#   'said',
#   'see',
#   'did',
#   'would',
#   'stopped',
#   'artists',
#   'every'],
#  'situation': ['come'],
#  'extort': ['money'],
#  'weren': ['even', 'vegan'],
#  'suck': ['watch'],
#  'watch': ['get', 'marvin', 'walk', 'the'],
#  'phone': ['call', 'call', 'and', 'text', 'was'],
#  'call': ['from',
#   'and',
#   'was',
#   'with',
#   'were',
#   'the',
#   'like',
#   'and',
#   'know',
#   'the'],
#  'reached': ['out', 'out', 'out', 'out', 'out', 'out', 'out'],
#  'claiming': ['have'],
#  'video': ['footage'],
#  'footage': ['being', 'tmz', 'they', 'out', 'watching'],
#  'being': ['inappropriate',
#   'super',
#   'part',
#   'little',
#   'his',
#   'whore',
#   'brand',
#   'hunted'],
#  'inappropriate': ['with'],
#  'models': ['yeah', 'maybe', 'they'],
#  'disrespect': ['any', 'cats'],
#  'woman': ['who', 'was', 'other'],
#  'none': ['them'],
#  'maybe': ['couple',
#   'but',
#   'modernize',
#   'your',
#   'just',
#   'can',
#   'you',
#   'you',
#   'you',
#   'not'],
#  'couple': ['cochinas',
#   'comics',
#   'tweets',
#   'minor',
#   'minor',
#   'here',
#   'minutes',
#   'more',
#   'years'],
#  'cochinas': ['from'],
#  'covina': ['maybe'],
#  'citizens': ['thank'],
#  'until': ['make', 'too', 'gets'],
#  'deposit': ['into'],
#  'account': ['they'],
#  'release': ['the'],
#  'tmz': ['and'],
#  'career': ['was', 'worth', 'and', 'the', 'think', 'this'],
#  'message': ['was', 'basically', 'ding'],
#  'missed': ['the'],
#  'deadline': ['half'],
#  'job': ['and',
#   'security',
#   'went',
#   'would',
#   'the',
#   'opening',
#   'nobody',
#   'you',
#   'you',
#   'thank',
#   'was'],
#  'hearing': ['about', 'this'],
#  'scare': ['into'],
#  'giving': ['them', 'you'],
#  'seriously': ['that'],
#  'wrong': ['when', 'understand', 'for', 'person', 'way', 'way'],
#  'lot': ['money',
#   'had',
#   'more',
#   'times',
#   'people',
#   'the',
#   'the',
#   'basic',
#   'the',
#   'with',
#   'you',
#   'look',
#   'people'],
#  'celebrity': ['really'],
#  'low': ['like'],
#  'perspective': ['they'],
#  'kevin': ['hart',
#   'hart',
#   'hart',
#   'hart',
#   'hart',
#   'hart',
#   'hart',
#   'can',
#   'was',
#   'glad',
#   'said',
#   'said',
#   'hart',
#   'hart',
#   'hart',
#   'hart'],
#  'hart': ['and',
#   'they',
#   'with',
#   'was',
#   'was',
#   'had',
#   'about',
#   'which',
#   'drama',
#   'front',
#   'can'],
#  'hit': ['him', 'record', 'record', 'him', 'him', 'you', 'that', 'the'],
#  'ten': ['million',
#   'million',
#   'million',
#   'minutes',
#   'years',
#   'years',
#   'years',
#   'years',
#   'seconds'],
#  'million': ['ten', 'which', 'and', 'struggles'],
#  'which': ['lets', 'case', 'basically', 'nice', 'not', 'the', 'like'],
#  'lets': ['know'],
#  'stand': ['the', 'one', 'was', 'and', 'comedy'],
#  'totem': ['pole'],
#  'pole': ['success'],
#  'success': ['there'],
#  'groupon': ['extortion'],
#  'extortion': ['where', 'got'],
#  'ross': ['clearance'],
#  'clearance': ['fifty'],
#  'fifty': ['thousand', 'thousand'],
#  'thousand': ['dollars', 'dollars'],
#  'dollars': ['you', 'but'],
#  'buy': ['escalade'],
#  'escalade': ['with'],
#  'hyundai': ['sonata'],
#  'sonata': ['best'],
#  'best': ['okay', 'understanding', 'fighters', 'fighters', 'year', 'thing'],
#  'base': ['model'],
#  'model': ['you'],
#  'happier': ['note'],
#  'note': ['did'],
#  'manage': ['stay'],
#  'busy': ['during'],
#  'movie': ['from', 'already', 'with', 'don', 'sound', 'for'],
#  'pornhub': ['the'],
#  'called': ['space',
#   'job',
#   'what',
#   'was',
#   'and',
#   'fat',
#   'shaming',
#   'home',
#   'the'],
#  'space': ['jam', 'jam', 'jam'],
#  'jam': ['the', 'and', 'new'],
#  'lebron': ['los'],
#  'speedy': ['gonzales',
#   'gonzales',
#   'now',
#   'gonzales',
#   'you',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales',
#   'gonzales'],
#  'gonzales': ['thank',
#   'sure',
#   'what',
#   'you',
#   'said',
#   'was',
#   'said',
#   'they',
#   'gonna',
#   'take',
#   'the',
#   'again'],
#  'ironic': ['that'],
#  'hired': ['the'],
#  'slowest': ['mexican'],
#  'play': ['the', 'the', 'nice', 'and', 'and', 'and', 'listened'],
#  'fastest': ['you', 'mouse'],
#  'part': ['come', 'this', 'now', 'about', 'his', 'that'],
#  'cancel': ['speedy',
#   'him',
#   'catch',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture'],
#  'cartoons': ['they'],
#  'pep': ['pew', 'understand'],
#  'pew': ['and'],
#  'touchy': ['you'],
#  'disguises': ['with'],
#  'mon': ['mon', 'lah'],
#  'lah': ['ohhh'],
#  'ohhh': ['yeah'],
#  'crime': ['mexican', 'montebello', 'was'],
#  'fast': ['that', 'forward'],
#  'montebello': ['that'],
#  'security': ['said', 'and', 'and', 'sees', 'was', 'clueless'],
#  'cannot': ['let', 'cancel', 'speak', 'miss', 'host', 'control', 'tell'],
#  'hurt': ['speedy', 'let', 'credibility'],
#  'defense': ['plus'],
#  'place': ['felt', 'you', 'good', 'and'],
#  'felt': ['could', 'little', 'because', 'this', 'sad'],
#  'protect': ['him'],
#  'twitter': ['and', 'ooh', 'scary', 'looking', 'with', 'feed', 'feed'],
#  'ooh': ['twitter'],
#  'scary': ['place'],
#  'fight': ['get',
#   'unless',
#   'hear',
#   'canelo',
#   'this',
#   'against',
#   'well',
#   'off'],
#  'prove': ['point', 'point'],
#  'mine': ['said', 'too', 'the', 'and', 'and'],
#  'attention': ['use', 'again', 'don', 'just', 'because', 'the'],
#  'use': ['hashtag', 'organically'],
#  'hashtag': ['and'],
#  'wrote': ['tweet', 'out', 'the'],
#  'tweet': ['that', 'and', 'fox', 'one', 'come', 'and', 'that'],
#  'cancelculture': ['name'],
#  'catch': ['and'],
#  'posted': ['had', 'tweet', 'picture'],
#  'problems': ['you'],
#  'every': ['major',
#   'time',
#   'stereotype',
#   'single',
#   'other',
#   'single',
#   'little',
#   'single',
#   'year',
#   'color',
#   'single',
#   'single',
#   'single',
#   'background',
#   'neighborhood',
#   'man'],
#  'major': ['news'],
#  'outlet': ['picked'],
#  'picked': ['tweet'],
#  'culture': ['abc', 'works', 'already', 'they', 'and'],
#  'abc': ['nbc'],
#  'nbc': ['cbs'],
#  'cbs': ['cnn'],
#  'cnn': ['would'],
#  'known': ['that', 'make', 'one', 'that'],
#  'spellcheck': ['cause'],
#  'spell': ['correctly'],
#  'correctly': ['god'],
#  'fox': ['news', 'news', 'news'],
#  'bus': ['driver', 'the'],
#  'driver': ['dave'],
#  'dave': ['called', 'shut', 'chappelle', 'chappelle'],
#  'thrilled': ['was', 'hear'],
#  'prouder': ['you'],
#  'baby': ['you',
#   'powder',
#   'talk',
#   'you',
#   'get',
#   'had',
#   'there',
#   'sounds',
#   'shark',
#   'shark',
#   'shark',
#   'shark',
#   'shark',
#   'bear',
#   'bear'],
#  'america': ['even'],
#  'warner': ['bros', 'bros', 'bros'],
#  'bros': ['pictures', 'gets', 'pictures'],
#  'pictures': ['reached', 'here'],
#  'zoom': ['call', 'and', 'call', 'call'],
#  'kind': ['convenient', 'stuttering', 'miss', 'drink'],
#  'convenient': ['right', 'the'],
#  'entertain': ['myself'],
#  'took': ['zoom', 'the', 'down'],
#  'full': ['winnie', 'winnie', 'blown', 'black'],
#  'winnie': ['the', 'the'],
#  'pooh': ['and', 'was'],
#  'laughing': ['now', 'cause', 'just'],
#  'leaving': ['baby', 'taco', 'see'],
#  'powder': ['all'],
#  'looked': ['like', 'and', 'like', 'like'],
#  'episode': ['narcos'],
#  'narcos': ['get'],
#  'director': ['writer', 'writer', 'just'],
#  'writer': ['and', 'and'],
#  'producer': ['space', 'all', 'also', 'the'],
#  'super': ['nice', 'supportive', 'cool', 'white', 'white', 'bowl', 'rare'],
#  'nice': ['super', 'here', 'least', 'pleasant'],
#  'supportive': ['super'],
#  'cool': ['they', 'that', 'that', 'will', 'grab'],
#  'lending': ['your'],
#  'talents': ['our'],
#  'appreciate': ['you', 'the', 'that'],
#  'questions': ['concerns', 'one', 'about'],
#  'concerns': ['let'],
#  'question': ['for',
#   'well',
#   'has',
#   'whether',
#   'that',
#   'gotten',
#   'people',
#   'monday'],
#  'thoughts': ['said'],
#  'met': ['family', 'the'],
#  'speak': ['for', 'english', 'your', 'for'],
#  'brown': ['people', 'shield', 'person'],
#  'personally': ['house'],
#  'growing': ['speedy', 'was'],
#  'viewed': ['negative'],
#  'negative': ['way', 'nothing'],
#  'matter': ['fact', 'time', 'what', 'what', 'what'],
#  'representation': ['had'],
#  'bumblebee': ['the'],
#  'simpsons': ['gabriel'],
#  'perhaps': ['you'],
#  'lend': ['your'],
#  'speaking': ['voice'],
#  'character': ['maybe', 'but', 'said'],
#  'modernize': ['him'],
#  'bring': ['him', 'that', 'this', 'this'],
#  'speed': ['said', 'and'],
#  'due': ['respect'],
#  'respect': ['appreciate'],
#  'power': ['change', 'cancel'],
#  'change': ['the', 'your', 'now', 'the', 'that'],
#  'such': ['iconic', 'technical', 'detail', 'story'],
#  'iconic': ['character'],
#  'asked': ['the', 'over'],
#  'auditioned': ['for'],
#  'assumed': ['that'],
#  'voices': ['for', 'for'],
#  'says': ['what', 'gyro', 'get', 'you'],
#  'choose': ['you'],
#  'whether': ['not', 'not', 'about', 'not'],
#  'needed': ['big', 'step', 'was'],
#  'shield': ['case'],
#  'three': ['people', 'were', 'will', 'how', 'bags', 'different', 'mexican'],
#  'worry': ['cause', 'about'],
#  'twofer': ['you'],
#  'actual': ['mexican'],
#  'does': ['recordings',
#   'not',
#   'english',
#   'that',
#   'the',
#   'know',
#   'know',
#   'this'],
#  'recordings': ['over'],
#  'loud': ['okay', 'where', 'have'],
#  'steven': ['the'],
#  'coordinator': ['warner'],
#  'talking': ['like',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'you'],
#  'flow': ['the'],
#  'tempo': ['the'],
#  'timing': ['and'],
#  'dialed': ['gonna'],
#  'sounds': ['good', 'good', 'crazy', 'good', 'and'],
#  'legacy': ['speedy'],
#  'mic': ['check'],
#  'check': ['sounds', 'next'],
#  'hola': ['amigos', 'walked', 'she'],
#  'amigos': ['name'],
#  'mouse': ['all'],
#  'mexico': ['arriba'],
#  'arriba': ['epa'],
#  'epa': ['epa', 'ndale'],
#  'ndale': ['the'],
#  'perfect': ['said'],
#  'long': ['time',
#   'way',
#   'way',
#   'beach',
#   'have',
#   'time',
#   'time',
#   'you',
#   'time',
#   'time',
#   'grab',
#   'beach'],
#  'entire': ['film', 'rim'],
#  'marvin': ['the'],
#  'martian': ['modulator'],
#  'modulator': ['yosemite'],
#  'yosemite': ['sam'],
#  'sam': ['hate'],
#  'hate': ['that'],
#  'rabbit': ['bugs'],
#  'bugs': ['bunny'],
#  'bunny': ['what'],
#  'doc': ['said'],
#  'fire': ['all'],
#  'actors': ['right', 'see'],
#  'medical': ['insurance'],
#  'insurance': ['and'],
#  'middle': ['meant'],
#  'meant': ['that', 'you'],
#  'pay': ['pay', 'favorite', 'per', 'per', 'for'],
#  'favorite': ['part', 'fighter', 'story'],
#  'actually': ['entertained', 'probably', 'the'],
#  'entertained': ['the'],
#  'conversation': ['like', 'went', 'can', 'with'],
#  'accepted': ['that'],
#  'guess': ['living', 'about', 'should', 'single', 'wasn', 'during'],
#  'times': ['where', 'simple'],
#  'sensitive': ['and'],
#  'mindful': ['and'],
#  'taking': ['anything', 'him', 'forever', 'too'],
#  'anything': ['away', 'for', 'happens', 'and', 'bad', 'you'],
#  'away': ['from',
#   'need',
#   'from',
#   'and',
#   'from',
#   'together',
#   'couple',
#   'from',
#   'like',
#   'the'],
#  'credibility': ['voice', 'that', 'image'],
#  'talent': ['entertainer'],
#  'entertainer': ['just'],
#  'individual': ['but'],
#  'hands': ['are', 'over', 'the'],
#  'tied': ['contracts'],
#  'contracts': ['have'],
#  'signed': ['checks', 'perform', 'piece', 'official'],
#  'checks': ['have'],
#  'cut': ['this'],
#  'union': ['project'],
#  'project': ['and'],
#  'also': ['this'],
#  'responsible': ['for'],
#  'finance': ['the'],
#  'hears': ['the', 'okay'],
#  'goin': ['down'],
#  'whoa': ['whoa', 'whoa', 'hold'],
#  'hold': ['hear', 'your', 'got'],
#  'hear': ['the',
#   'out',
#   'from',
#   'where',
#   'him',
#   'that',
#   'myself',
#   'this',
#   'you',
#   'these'],
#  'talk': ['puddin', 'about', 'about', 'them', 'person', 'you'],
#  'puddin': ['can'],
#  'talkin': ['said', 'what'],
#  'rate': ['what'],
#  'fee': ['said'],
#  'word': ['the', 'gets'],
#  'street': ['for', 'you', 'vendors', 'vendors', 'and', 'come', 'are'],
#  'emails': ['support'],
#  'support': ['that', 'mine', 'street', 'being'],
#  'defend': ['speedy'],
#  'unfortunately': ['that'],
#  'held': ['accountable', 'accountable', 'and', 'and', 'and'],
#  'accountable': ['but', 'for'],
#  'far': ['because', 'along'],
#  'pride': ['myself'],
#  'comedian': ['who', 'you', 'funnyman', 'have', 'when'],
#  'divisive': ['that'],
#  'politics': ['religion'],
#  'religion': ['sports'],
#  'sports': ['okay', 'bra'],
#  'divide': ['people'],
#  'food': ['because', 'brings', 'and', 'came'],
#  'unless': ['you', 'you', 'you'],
#  'vegan': ['which', 'know', 'for', 'then'],
#  'offend': ['you'],
#  'salad': ['you'],
#  'ugh': ['the', 'take', 'dick'],
#  'vegans': ['because', 'the'],
#  'once': ['was', 'set'],
#  'under': ['year'],
#  'probably': ['thinking', 'expect', 'the'],
#  'anyone': ['who', 'they', 'wondering', 'ever'],
#  'diet': ['knows'],
#  'hard': ['change', 'was', 'for'],
#  'eating': ['habits'],
#  'habits': ['for'],
#  'week': ['much'],
#  'weight': ['and', 'patience', 'pounds'],
#  'patience': ['and'],
#  'friends': ['just', 'the', 'and', 'and'],
#  'almost': ['got', 'got', 'got', 'hear', 'took', 'years', 'got', 'and'],
#  'canceled': ['almost', 'because', 'right', 'for'],
#  'chihuahuas': ['yeah', 'have', 'yeah', 'and', 'mix'],
#  'watching': ['home', 'show', 'train', 'and', 'this', 'this'],
#  'boy': ['dog'],
#  'dog': ['named',
#   'named',
#   'risa',
#   'owners',
#   'owners',
#   'what',
#   'will',
#   'vinnie',
#   'loves',
#   'loves',
#   'always'],
#  'named': ['vinnie', 'risa'],
#  'vinnie': ['and', 'will', 'this', 'this'],
#  'girl': ['dog', 'dog', 'barista', 'like', 'the', 'like', 'came'],
#  'risa': ['combined', 'she', 'they', 'they'],
#  'combined': ['weight'],
#  'anger': ['keeps'],
#  'keeps': ['her', 'kicking'],
#  'alive': ['will'],
#  'confirm': ['every'],
#  'stereotype': ['about'],
#  'rage': ['real'],
#  'loves': ['okay', 'more', 'more', 'much', 'more', 'more'],
#  'teeth': ['her'],
#  'tongue': ['hangs'],
#  'hangs': ['out'],
#  'adorable': ['posted', 'what', 'what'],
#  'picture': ['her'],
#  'caption': ['that'],
#  'read': ['going', 'headlines'],
#  'nugget': ['get'],
#  'chicken': ['nuggets'],
#  'nuggets': ['and'],
#  'tagged': ['chick', 'chick', 'chipotle'],
#  'chick': ['fil', 'fil', 'fil', 'fil', 'fil'],
#  'fil': ['okay', 'sorry', 'the', 'future', 'for'],
#  'majority': ['the'],
#  'sucks': ['they'],
#  'sunday': ['and'],
#  'groan': ['yeah'],
#  'blew': ['twitter'],
#  'feed': ['twitter', 'started'],
#  'getting': ['flooded', 'back', 'stressed', 'naked'],
#  'flooded': ['with'],
#  'nasty': ['comments'],
#  ...}

# %%
generate_sentence(gabriel_dict)
# Out:
# 'Lend your thing love love him didn want see this guy and said some laughs.'

# %% [markdown]
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
import string
def generate_sentence1(chain, count=20):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.
       Sentence ends with a punctuation mark, or when it gets to a word that already ends with a punctuation mark.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        sentence += ' ' + word2
        if word2[-1] in string.punctuation:
            break
        word1 = word2

    # End the sentence with a random punctuation mark
    sentence += random.choice(string.punctuation)
    return sentence

# %%
generate_sentence1(gabriel_dict)
# Out:
# 'Finally got from the movie sound coordinator warner bros pictures here comes big lebowski wow okay and look going let;'
